# %%
from utils.df_handle import *
# Out:
# Default bq project:  spatial-vision-343005.biteam

# %%
# Imports the Cloud Logging client library
import google.cloud.logging

# Instantiates a client
client = google.cloud.logging.Client()

# Retrieves a Cloud Logging handler based on the environment
# you're running in and integrates the handler with the
# Python logging module. By default this captures all logs
# at INFO level and higher
# client.setup_logging()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In [2], line 5
#       2 import google.cloud.logging
#       4 # Instantiates a client
# ----> 5 client = google.cloud.logging.Client()
#       7 # Retrieves a Cloud Logging handler based on the environment
#       8 # you're running in and integrates the handler with the
#       9 # Python logging module. By default this captures all logs
#      10 # at INFO level and higher
#      11 # client.setup_logging()
#
# File d:\ipython_file\env\lib\site-packages\google\cloud\logging_v2\client.py:118, in Client.__init__(self, project, credentials, _http, _use_grpc, client_info, client_options)
#      76 def __init__(
#      77     self,
#      78     *,
#    (...)
#      84     client_options=None,
#      85 ):
#      86     """
#      87     Args:
#      88         project (Optional[str]): the project which the client acts on behalf of.
#    (...)
#     116             on the client. API Endpoint should be set through client_options.
#     117         """
# --> 118     super(Client, self).__init__(
#     119         project=project,
#     120         credentials=credentials,
#     121         _http=_http,
#     122         client_options=client_options,
#     123     )
#     125     kw_args = {"client_info": client_info}
#     126     if client_options:
#
# File d:\ipython_file\env\lib\site-packages\google\cloud\client.py:318, in ClientWithProject.__init__(self, project, credentials, client_options, _http)
#     317 def __init__(self, project=None, credentials=None, client_options=None, _http=None):
# --> 318     _ClientProjectMixin.__init__(self, project=project, credentials=credentials)
#     319     Client.__init__(
#     320         self, credentials=credentials, client_options=client_options, _http=_http
#     321     )
#
# File d:\ipython_file\env\lib\site-packages\google\cloud\client.py:266, in _ClientProjectMixin.__init__(self, project, credentials)
#     263     project = getattr(credentials, "project_id", None)
#     265 if project is None:
# --> 266     project = self._determine_default(project)
#     268 if project is None:
#     269     raise EnvironmentError(
#     270         "Project was not passed and could not be "
#     271         "determined from the environment."
#     272     )
#
# File d:\ipython_file\env\lib\site-packages\google\cloud\client.py:285, in _ClientProjectMixin._determine_default(project)
#     282 @staticmethod
#     283 def _determine_default(project):
#     284     """Helper:  use default project detection."""
# --> 285     return _determine_default_project(project)
#
# File d:\ipython_file\env\lib\site-packages\google\cloud\_helpers.py:186, in _determine_default_project(project)
#     174 """Determine default project ID explicitly or implicitly as fall-back.
#     175
#     176 See :func:`google.auth.default` for details on how the default project
#    (...)
#     183 :returns: Default project if it can be determined.
#     184 """
#     185 if project is None:
# --> 186     _, project = google.auth.default()
#     187 return project
#
# File d:\ipython_file\env\lib\site-packages\google\auth\_default.py:488, in default(scopes, request, quota_project_id, default_scopes)
#     480             _LOGGER.warning(
#     481                 "No project ID could be determined. Consider running "
#     482                 "`gcloud config set project` or setting the %s "
#     483                 "environment variable",
#     484                 environment_vars.PROJECT,
#     485             )
#     486         return credentials, effective_project_id
# --> 488 raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started

# %%
# Imports the Google Cloud client library
from google.cloud import logging

# Instantiates a client
logging_client = logging.Client()

# %%
# logging_client.setup_logging()

# %%
from google.cloud import logging
logging_client = logging.Client()
log_name = "my-log"
logger = logging_client.logger(log_name)
# text = "Hello, world!"
# logger.log_text(text)

# %%
res = logger.log_struct(
    {
        "name": "King Arthur",
        "quest": "Find the Holy Grail",
        "favorite_color": "Blue",
    }
)

# %%
# pip install google-cloud-error-reporting

# %%
# import google.cloud.logging
# client = google.cloud.logging.Client()
# client.setup_logging()

# %%
for entry in logger.list_entries():
    timestamp = entry.timestamp.isoformat()
    print("* {}: {}".format(timestamp, entry.payload))
# Out:
# * 2022-10-11T13:46:33.753101+00:00: Hello, world!
# * 2022-10-11T13:57:43.804021+00:00: {'quest': 'Find the Holy Grail', 'favorite_color': 'Blue', 'name': 'King Arthur'}

# %%
# !pip freeze

# %%
from google.cloud import error_reporting
client = error_reporting.Client()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\ipython_file\cust_images\logger.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/ipython_file/cust_images/logger.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> from google.cloud import error_reporting
#       <a href='vscode-notebook-cell:/d%3A/ipython_file/cust_images/logger.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> client = error_reporting.Client()
#
# File d:\ipython_file\venv\lib\site-packages\google\cloud\error_reporting\__init__.py:22, in <module>
#      18 from pkg_resources import get_distribution
#      20 __version__ = get_distribution("google-cloud-error-reporting").version
# ---> 22 from google.cloud.error_reporting.client import Client
#      23 from google.cloud.error_reporting.client import HTTPContext
#      24 from google.cloud.error_reporting.util import build_flask_context
#
# File d:\ipython_file\venv\lib\site-packages\google\cloud\error_reporting\client.py:33, in <module>
#      31 from google.cloud.client import ClientWithProject
#      32 from google.cloud.error_reporting import __version__
# ---> 33 from google.cloud.error_reporting._logging import _ErrorReportingLoggingAPI
#      34 from google.cloud.environment_vars import DISABLE_GRPC
#      36 _DISABLE_GRPC = os.getenv(DISABLE_GRPC, False)
#
# File d:\ipython_file\venv\lib\site-packages\google\cloud\error_reporting\_logging.py:22, in <module>
#       1 # Copyright 2016 Google LLC All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 """Interact with Error Reporting via Logging API.
#      16
#      17 It's possible to report Error Reporting errors by formatting
#      18 structured log messages in Cloud Logging in a given format. This
#      19 client provides a mechanism to report errors using that technique.
#      20 """
# ---> 22 import google.cloud.logging
#      25 class _ErrorReportingLoggingAPI(object):
#      26     """Report to Error Reporting via Logging API
#      27
#      28     :type project: str
#    (...)
#      61         on the client. API Endpoint should be set through client_options.
#      62     """
#
# File d:\ipython_file\venv\lib\site-packages\google\cloud\logging\__init__.py:18, in <module>
#       1 # -*- coding: utf-8 -*-
#       2
#       3 # Copyright 2020 Google LLC
#    (...)
#      15 # limitations under the License.
#      16 #
# ---> 18 from google.cloud.logging_v2 import __version__
#      19 from google.cloud.logging_v2 import ASCENDING
#      20 from google.cloud.logging_v2 import DESCENDING
#
# File d:\ipython_file\venv\lib\site-packages\google\cloud\logging_v2\__init__.py:25, in <module>
#      21 except pkg_resources.DistributionNotFound:
#      22     __version__ = None
# ---> 25 from google.cloud.logging_v2.client import Client
#      26 from google.cloud.logging_v2.entries import logger_name_from_path
#      27 from google.cloud.logging_v2.entries import LogEntry
#
# File d:\ipython_file\venv\lib\site-packages\google\cloud\logging_v2\client.py:22, in <module>
#      19 import sys
#      21 try:
# ---> 22     from google.cloud.logging_v2 import _gapic
#      23 except ImportError:  # pragma: NO COVER
#      24     _HAVE_GRPC = False
#
# File d:\ipython_file\venv\lib\site-packages\google\cloud\logging_v2\_gapic.py:34, in <module>
#      31 from google.protobuf.json_format import MessageToDict
#      32 from google.protobuf.json_format import ParseDict
# ---> 34 from google.cloud.logging_v2._helpers import entry_from_resource
#      35 from google.cloud.logging_v2.sink import Sink
#      36 from google.cloud.logging_v2.metric import Metric
#
# File d:\ipython_file\venv\lib\site-packages\google\cloud\logging_v2\_helpers.py:25, in <module>
#      21 from datetime import timezone
#      23 import requests
# ---> 25 from google.cloud.logging_v2.entries import LogEntry
#      26 from google.cloud.logging_v2.entries import ProtobufEntry
#      27 from google.cloud.logging_v2.entries import StructEntry
#
# File d:\ipython_file\venv\lib\site-packages\google\cloud\logging_v2\entries.py:31, in <module>
#      28 from google.cloud._helpers import _datetime_to_rfc3339
#      30 # import officially supported proto definitions
# ---> 31 import google.cloud.audit.audit_log_pb2  # noqa: F401
#      32 import google.cloud.appengine_logging  # noqa: F401
#      34 _GLOBAL_RESOURCE = Resource(type="global", labels={})
#
# File d:\ipython_file\venv\lib\site-packages\google\cloud\audit\audit_log_pb2.py:60, in <module>
#      35 from google.rpc import status_pb2 as google_dot_rpc_dot_status__pb2
#      38 DESCRIPTOR = _descriptor.FileDescriptor(
#      39     name="google/cloud/audit/audit_log.proto",
#      40     package="google.cloud.audit",
#    (...)
#      49     ],
#      50 )
#      53 _AUDITLOG = _descriptor.Descriptor(
#      54     name="AuditLog",
#      55     full_name="google.cloud.audit.AuditLog",
#      56     filename=None,
#      57     file=DESCRIPTOR,
#      58     containing_type=None,
#      59     fields=[
# ---> 60         _descriptor.FieldDescriptor(
#      61             name="service_name",
#      62             full_name="google.cloud.audit.AuditLog.service_name",
#      63             index=0,
#      64             number=7,
#      65             type=9,
#      66             cpp_type=9,
#      67             label=1,
#      68             has_default_value=False,
#      69             default_value=b"".decode("utf-8"),
#      70             message_type=None,
#      71             enum_type=None,
#      72             containing_type=None,
#      73             is_extension=False,
#      74             extension_scope=None,
#      75             serialized_options=None,
#      76             file=DESCRIPTOR,
#      77         ),
#      78         _descriptor.FieldDescriptor(
#      79             name="method_name",
#      80             full_name="google.cloud.audit.AuditLog.method_name",
#      81             index=1,
#      82             number=8,
#      83             type=9,
#      84             cpp_type=9,
#      85             label=1,
#      86             has_default_value=False,
#      87             default_value=b"".decode("utf-8"),
#      88             message_type=None,
#      89             enum_type=None,
#      90             containing_type=None,
#      91             is_extension=False,
#      92             extension_scope=None,
#      93             serialized_options=None,
#      94             file=DESCRIPTOR,
#      95         ),
#      96         _descriptor.FieldDescriptor(
#      97             name="resource_name",
#      98             full_name="google.cloud.audit.AuditLog.resource_name",
#      99             index=2,
#     100             number=11,
#     101             type=9,
#     102             cpp_type=9,
#     103             label=1,
#     104             has_default_value=False,
#     105             default_value=b"".decode("utf-8"),
#     106             message_type=None,
#     107             enum_type=None,
#     108             containing_type=None,
#     109             is_extension=False,
#     110             extension_scope=None,
#     111             serialized_options=None,
#     112             file=DESCRIPTOR,
#     113         ),
#     114         _descriptor.FieldDescriptor(
#     115             name="resource_location",
#     116             full_name="google.cloud.audit.AuditLog.resource_location",
#     117             index=3,
#     118             number=20,
#     119             type=11,
#     120             cpp_type=10,
#     121             label=1,
#     122             has_default_value=False,
#     123             default_value=None,
#     124             message_type=None,
#     125             enum_type=None,
#     126             containing_type=None,
#     127             is_extension=False,
#     128             extension_scope=None,
#     129             serialized_options=None,
#     130             file=DESCRIPTOR,
#     131         ),
#     132         _descriptor.FieldDescriptor(
#     133             name="resource_original_state",
#     134             full_name="google.cloud.audit.AuditLog.resource_original_state",
#     135             index=4,
#     136             number=19,
#     137             type=11,
#     138             cpp_type=10,
#     139             label=1,
#     140             has_default_value=False,
#     141             default_value=None,
#     142             message_type=None,
#     143             enum_type=None,
#     144             containing_type=None,
#     145             is_extension=False,
#     146             extension_scope=None,
#     147             serialized_options=None,
#     148             file=DESCRIPTOR,
#     149         ),
#     150         _descriptor.FieldDescriptor(
#     151             name="num_response_items",
#     152             full_name="google.cloud.audit.AuditLog.num_response_items",
#     153             index=5,
#     154             number=12,
#     155             type=3,
#     156             cpp_type=2,
#     157             label=1,
#     158             has_default_value=False,
#     159             default_value=0,
#     160             message_type=None,
#     161             enum_type=None,
#     162             containing_type=None,
#     163             is_extension=False,
#     164             extension_scope=None,
#     165             serialized_options=None,
#     166             file=DESCRIPTOR,
#     167         ),
#     168         _descriptor.FieldDescriptor(
#     169             name="status",
#     170             full_name="google.cloud.audit.AuditLog.status",
#     171             index=6,
#     172             number=2,
#     173             type=11,
#     174             cpp_type=10,
#     175             label=1,
#     176             has_default_value=False,
#     177             default_value=None,
#     178             message_type=None,
#     179             enum_type=None,
#     180             containing_type=None,
#     181             is_extension=False,
#     182             extension_scope=None,
#     183             serialized_options=None,
#     184             file=DESCRIPTOR,
#     185         ),
#     186         _descriptor.FieldDescriptor(
#     187             name="authentication_info",
#     188             full_name="google.cloud.audit.AuditLog.authentication_info",
#     189             index=7,
#     190             number=3,
#     191             type=11,
#     192             cpp_type=10,
#     193             label=1,
#     194             has_default_value=False,
#     195             default_value=None,
#     196             message_type=None,
#     197             enum_type=None,
#     198             containing_type=None,
#     199             is_extension=False,
#     200             extension_scope=None,
#     201             serialized_options=None,
#     202             file=DESCRIPTOR,
#     203         ),
#     204         _descriptor.FieldDescriptor(
#     205             name="authorization_info",
#     206             full_name="google.cloud.audit.AuditLog.authorization_info",
#     207             index=8,
#     208             number=9,
#     209             type=11,
#     210             cpp_type=10,
#     211             label=3,
#     212             has_default_value=False,
#     213             default_value=[],
#     214             message_type=None,
#     215             enum_type=None,
#     216             containing_type=None,
#     217             is_extension=False,
#     218             extension_scope=None,
#     219             serialized_options=None,
#     220             file=DESCRIPTOR,
#     221         ),
#     222         _descriptor.FieldDescriptor(
#     223             name="request_metadata",
#     224             full_name="google.cloud.audit.AuditLog.request_metadata",
#     225             index=9,
#     226             number=4,
#     227             type=11,
#     228             cpp_type=10,
#     229             label=1,
#     230             has_default_value=False,
#     231             default_value=None,
#     232             message_type=None,
#     233             enum_type=None,
#     234             containing_type=None,
#     235             is_extension=False,
#     236             extension_scope=None,
#     237             serialized_options=None,
#     238             file=DESCRIPTOR,
#     239         ),
#     240         _descriptor.FieldDescriptor(
#     241             name="request",
#     242             full_name="google.cloud.audit.AuditLog.request",
#     243             index=10,
#     244             number=16,
#     245             type=11,
#     246             cpp_type=10,
#     247             label=1,
#     248             has_default_value=False,
#     249             default_value=None,
#     250             message_type=None,
#     251             enum_type=None,
#     252             containing_type=None,
#     253             is_extension=False,
#     254             extension_scope=None,
#     255             serialized_options=None,
#     256             file=DESCRIPTOR,
#     257         ),
#     258         _descriptor.FieldDescriptor(
#     259             name="response",
#     260             full_name="google.cloud.audit.AuditLog.response",
#     261             index=11,
#     262             number=17,
#     263             type=11,
#     264             cpp_type=10,
#     265             label=1,
#     266             has_default_value=False,
#     267             default_value=None,
#     268             message_type=None,
#     269             enum_type=None,
#     270             containing_type=None,
#     271             is_extension=False,
#     272             extension_scope=None,
#     273             serialized_options=None,
#     274             file=DESCRIPTOR,
#     275         ),
#     276         _descriptor.FieldDescriptor(
#     277             name="metadata",
#     278             full_name="google.cloud.audit.AuditLog.metadata",
#     279             index=12,
#     280             number=18,
#     281             type=11,
#     282             cpp_type=10,
#     283             label=1,
#     284             has_default_value=False,
#     285             default_value=None,
#     286             message_type=None,
#     287             enum_type=None,
#     288             containing_type=None,
#     289             is_extension=False,
#     290             extension_scope=None,
#     291             serialized_options=None,
#     292             file=DESCRIPTOR,
#     293         ),
#     294         _descriptor.FieldDescriptor(
#     295             name="service_data",
#     296             full_name="google.cloud.audit.AuditLog.service_data",
#     297             index=13,
#     298             number=15,
#     299             type=11,
#     300             cpp_type=10,
#     301             label=1,
#     302             has_default_value=False,
#     303             default_value=None,
#     304             message_type=None,
#     305             enum_type=None,
#     306             containing_type=None,
#     307             is_extension=False,
#     308             extension_scope=None,
#     309             serialized_options=None,
#     310             file=DESCRIPTOR,
#     311         ),
#     312     ],
#     313     extensions=[],
#     314     nested_types=[],
#     315     enum_types=[],
#     316     serialized_options=None,
#     317     is_extendable=False,
#     318     syntax="proto3",
#     319     extension_ranges=[],
#     320     oneofs=[],
#     321     serialized_start=185,
#     322     serialized_end=819,
#     323 )
#     326 _AUTHENTICATIONINFO = _descriptor.Descriptor(
#     327     name="AuthenticationInfo",
#     328     full_name="google.cloud.audit.AuthenticationInfo",
#    (...)
#     451     serialized_end=1103,
#     452 )
#     455 _AUTHORIZATIONINFO = _descriptor.Descriptor(
#     456     name="AuthorizationInfo",
#     457     full_name="google.cloud.audit.AuthorizationInfo",
#    (...)
#     544     serialized_end=1256,
#     545 )
#
# File d:\ipython_file\venv\lib\site-packages\google\protobuf\descriptor.py:560, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     554 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     555             default_value, message_type, enum_type, containing_type,
#     556             is_extension, extension_scope, options=None,
#     557             serialized_options=None,
#     558             has_default_value=True, containing_oneof=None, json_name=None,
#     559             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 560   _message.Message._CheckCalledFromGeneratedFile()
#     561   if is_extension:
#     562     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
import traceback

# %%
try:
    1/0
except ZeroDivisionError as e:
    print(traceback.format_exc())
    # logger.log_text(traceback.format_exc(), severity="ERROR")
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Van Quang Duy\AppData\Local\Temp\ipykernel_1928\2600681796.py", line 2, in <cell line: 1>
#     1/0
# ZeroDivisionError: division by zero
