# %% [markdown]
# **bold text**
#
# *italicized text*

# %% [markdown]
# # **ASCII, UNICODE, UTF-8, codepoints**
#
# escape sequences, ord(), chr(), literals
#
# indexing, slicing, immutability, iterating through
#
# concatenating, multiplying, comparing (against strings and numbes)
#
# in, not in
#
# .isxxx(), .join(), .split()
#
# .sort(), sorted(), .index(), .find(), .rfind()

# %% [markdown]
# The one named **ASCII** (short for American Standard Code for Information Interchange) is the most widely used,
# and you can assume that nearly all modern devices (like computers, printers, mobile phones, tablets, etc.) use that code.

# %% [markdown]
# The code provides space for 256 different characters, but we are interested only in the first 128. If you want to see how the code is constructed, look at the table below. Click the table to enlarge it. Look at it carefully - there are some interesting facts. Look at the code of the most common character - the space. This is 32.

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# **A code point** is a number which makes a character. For example, 32 is a code point which makes a space in ASCII encoding. We can say that standard ASCII code consists of 128 code points.

# %% [markdown]
# **A code page** is a standard for using the upper 128 code points to store specific national characters. For example, there are different code pages for Western Europe and Eastern Europe, Cyrillic and Greek alphabets, Arabic and Hebrew languages, and so on.

# %% [markdown]
# *For example, the code point 200 makes Č (a letter used by some Slavic languages) when utilized by the ISO/IEC 8859-2 code page, and makes Ш (a Cyrillic letter) when used by the ISO/IEC 8859-5 code page.
# In consequence, to determine the meaning of a specific code point, you have to know the target code page.*

# %% [markdown]
# **Unicode** assigns unique (unambiguous) characters (letters, hyphens, ideograms, etc.) to more than a million code points.
#
# The first 128 Unicode code points are identical to ASCII, and the first 256 Unicode code points are identical to the ISO/IEC 8859-1 code page (a code page designed for western European languages).

# %% [markdown]
# One of the most commonly used is **UTF-8**.
#
# The name is derived from Unicode Transformation Format.
#
# The concept is very smart. UTF-8 uses as many bits for each of the code points as it really needs to represent them.

# %% [markdown]
# *For example:
# all Latin characters (and all standard ASCII characters) occupy eight bits;
# non-Latin characters occupy 16 bits;*
#
# *CJK (China-Japan-Korea) ideographs occupy 24 bits.
# Due to features of the method used by UTF-8 to store the code points, there is no need to use the BOM, but some of the tools look for it when reading the file, and many editors set it up during the save.*
#
# *Python 3 fully supports Unicode and UTF-8:
# you can use Unicode/UTF-8 encoded characters to name variables and other entities; you can use them during all input and output. This means that Python3 is completely **I18Ned***

# %% [markdown]
# **There are some interesting facts about ASCII which are worth mentioning:**
#
# • decimal digit code points occupy values from 48 (0x30) ("0") to 57 (0x39) ("9")
#
# • the space code point is 32 (0x20)
#
# • upper-case Latin letters occupy the code points from the range 65 (0x41) ("A") to 90
# (0x5A) ("Z").
#
# • lower-case Latin letters use values from 97 (0x61) ("a") to 122 (0x7A) ("z").
#
# • note that any lower-case letter code point is **greater by 32** (a space code point) than its
# upper-case counterpart.

# %% [markdown]
# # **escape sequences, ord(), chr(), literals**

# %% [markdown]
#  Python's strings = **immutable sequences.**
#
# Take a look at Example 1. The len() function used for strings returns a number of characters contained by the arguments. The snippet outputs 2.
#
# Any string can be empty. Its length is 0 then - just like in Example 2.
#
# Don't forget that a backslash (\) used as an **escape character** is **not** included in the string's total length. The code in Example 3, therefore, outputs 3.

# %% [markdown]
# **The multiline strings can be delimited by triple quotes**

# %%
multiline = '''Line #1
Line #2'''

print(len(multiline))
# Out:
# 15

# %%
multiline = '''Line #1\nLine #2'''
print(multiline)
print(len(multiline))
# Out:
# Line #1
# Line #2
# 15

# %% [markdown]
# **An empty string is a string that contains no characters. All the strings below are empty:**

# %%
x1 = ''

x2 = ""

x3 = ''''''

x4 = """"""

print(len(x1))
print(len(x2))
print(len(x3))
print(len(x4))
# Out:
# 0
# 0
# 0
# 0

# %% [markdown]
# **Embedded apostrophe**
#
# If an apostrophe has to be embedded inside an apostrophe-delimited string,
#
# the inner apostrophe must be preceded (escaped) by a backslash
#
# The same rule applies to quotes located inside quote-delimited strings.

# %%
print('King\'s College')

print("King\"s College")
# Out:
# King's College
# King"s College

# %% [markdown]
# **Operations on strings: ord()**
#
# *one-character string as its argument - breaching this requirement causes a TypeError*

# %%
char_1 = 'a'
char_2 = ' '  # space

print(ord(char_1))
print(ord(char_2))
# Out:
# 97
# 32

# %% [markdown]
# **Operations on strings: chr()**
#
# *The function takes a code point and returns its character.*

# %%
print(chr(97))
print(chr(945))
print(chr(32))

'''
Note:
chr(ord(x)) == x
ord(chr(x)) == x
'''
# Out:
# a
# α
# '\nNote:\nchr(ord(x)) == x\nord(chr(x)) == x\n'

# %% [markdown]
# # **Indexing, slicing, immutability, iterating through**

# %% [markdown]
# **indexing**

# %%
# Indexing strings.

the_string = 'silly walks'

for ix in range(len(the_string)):
    print(the_string[ix], end=' ')

print()
# Out:
# s i l l y   w a l k s

# %% [markdown]
# **iterating**

# %%
# Iterating through a string.

the_string = 'silly walks'

for character in the_string:
    print(character, end=' ')

print()
# Out:
# s i l l y   w a l k s

# %% [markdown]
# **slices**

# %%
# Slices

alpha = "abdefg"
print (alpha[-1])
print("1:3 abdefg ",alpha[1:3])
print("3: abdefg ",alpha[3:])
print(":3 abdefg ",alpha[:3])
print(":-1 abdefg ",alpha[:-1])
print(":-2 abdefg ",alpha[:-2])
print("3:-2 abdefg ",alpha[3:-2])
print("-3: abdefg ", alpha[-3:])
print("-1: abdefg ", alpha[-1:])
print("-3:4 abdefg ", alpha[-3:4])
print("::2 abdefg",alpha[::2])
print('')
print("::-1 abdefg",alpha[::-1])
print('::-2 abdefg ',alpha[::-2])
print('1::2 abdefg ',alpha[1::2])
# Out:
# g
# 1:3 abdefg  bd
# 3: abdefg  efg
# :3 abdefg  abd
# :-1 abdefg  abdef
# :-2 abdefg  abde
# 3:-2 abdefg  e
# -3: abdefg  efg
# -1: abdefg  g
# -3:4 abdefg  e
# ::2 abdefg adf
#
# ::-1 abdefg gfedba
# ::-2 abdefg  geb
# 1::2 abdefg  beg

# %%
# Note: the slice which breaks string boundaries does not raise an exception
# The nonexistent characters are replaced by empty strings instead:

print("string"[2:100])
# Out:
# ring

# %% [markdown]
# **immutable**
#
# This primarily means that the similarity of strings and lists is limited. Not everything you can do with a list may be done with a string.
#
# The first important difference doesn't allow you to use the del instruction to remove anything from a string.
#
# The only thing you can do with del and a string is to **remove the string as a whole**. Try to do it.

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"
del alphabet[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-7799068dcbb8> in <module>()
#       1 alphabet = "abcdefghijklmnopqrstuvwxyz"
# ----> 2 del alphabet[0]
#
# TypeError: 'str' object doesn't support item deletion

# %%
del(alphabet)

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"
alphabet.append("A")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-62e2db4a5075> in <module>()
#       1 alphabet = "abcdefghijklmnopqrstuvwxyz"
# ----> 2 alphabet.append("A")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"
alphabet.insert("A")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-9a4ecf838bec> in <module>()
#       1 alphabet = "abcdefghijklmnopqrstuvwxyz"
# ----> 2 alphabet.insert("A")
#
# AttributeError: 'str' object has no attribute 'insert'

# %% [markdown]
# # **in, not in**

# %%
# The in operator, it simply checks if its left argument (a string) can be found anywhere within the right argument (another string).
# The result of the check is simply True or False.

# %%
alphabet = "abcdefghijklmnopqrstuvwxyz"

print("f" in alphabet)
print("F" in alphabet)
print("1" in alphabet)
print("ghi" in alphabet)
print("Xyz" in alphabet)
# Out:
# True
# False
# False
# True
# False

# %%
# The not in operator

alphabet = "abcdefghijklmnopqrstuvwxyz"

print("f" not in alphabet)
print("F" not in alphabet)
print("1" not in alphabet)
print("ghi" not in alphabet)
print("Xyz" not in alphabet)
# Out:
# False
# True
# True
# False
# True

# %%
# Note that c not in s is not the equivalent of not c in s – be aware of this!

print("F" in alphabet)

print("F" not in alphabet)

print(not "F" in alphabet)
# Out:
# False
# True
# True

# %% [markdown]
# It can be said that an empty string is contained inside **EVERY** string, even an empty one.
#
# Note that the expression below is always true, even if the right operand is an empty string

# %%
print("" in "string")

print("" in '')
# Out:
# True
# True

# %% [markdown]
# an apostrophe can be used in a string delimited by double quotes
#
# (and vice versa -double quotes can be used in a string delimited by single quotes).

# %%
print("Duy say 'NI")

print('Duy say "NI')
# Out:
# Duy say 'NI
# Duy say "NI

# %% [markdown]
# # **Concatenating, multiplying, comparing (against strings and numbes)**

# %% [markdown]
# **Concatenating**

# %%
alphabet = "bcdefghijklmnopqrstuvwxy"

alphabet = "a" + alphabet
alphabet = alphabet + "z"

print(alphabet)
# Out:
# abcdefghijklmnopqrstuvwxyz

# %% [markdown]
# It creating a new copy of a string each time you modify.
#
# its contents worsens the effectiveness of the code.
#
# Yes, it does. A bit. It's not a problem at all, though.

# %% [markdown]
# **multiplying**

# %%
# Strings can be concatenated using the + operator, and replicated using the * operator

x = 'ABC'

print(x*4)
# Out:
# ABCABCABCABC

# %% [markdown]
# **comparing**
#
# min()
#
# The function finds the minimum element of the sequence passed as an argument. There is one condition - the sequence (string, list, it doesn't matter) cannot be empty, or else you'll get a ValueError exception.
#
# max()

# %%
# Demonstrating min() - Example 1:
print(min("aAbByYzZ"))
print("")
for i in ("aAbByYzZ"):
  print(i,ord(i))


# Demonstrating min() - Examples 2 & 3:
t = 'The Knights Who Say "Ni!"'
print("min t: ", min(t))
print('[' + min(t) + ']')

print("min t is 32, its a space")

t = [0, 1, 2]
print(min(t))
# Out:
# A
#
# a 97
# A 65
# b 98
# B 66
# y 121
# Y 89
# z 122
# Z 90
# min t:
# [ ]
# min t is 32, its a space
# 0

# %%
t = 'The Knights Who Say "Ni!"'
for i in t:
  print(ord(i))
# Out:
# 84
# 104
# 101
# 32
# 75
# 110
# 105
# 103
# 104
# 116
# 115
# 32
# 87
# 104
# 111
# 32
# 83
# 97
# 121
# 32
# 34
# 78
# 105
# 33
# 34

# %%
# Demonstrating max() - Example 1:
print(max("aAbByYzZ"))


# Demonstrating max() - Examples 2 & 3:
t = 'The Knights Who Say "Ni!"'
print('[' + max(t) + ']')

t = [0, 1, 2]
print(max(t))
# Out:
# z
# [y]
# 2

# %% [markdown]
# Python's strings can be compared using the same set of operators
#
# **it just compares code point values**
#
# **comparing the first different character in both strings**
#
# When you compare two strings of different lengths and the shorter one is identical to the longer one's beginning, **the longer string is considered greater.**
#
# String comparison is always case-sensitive **(upper-case letters are taken as lesser than lower-case).**

# %%
'alpha' == 'alpha'
'alpha' != 'Alpha'
# Out:
# True

# %%
'beta' > 'Beta'
# Out:
# True

# %%
'alpha' < 'alphabet'
# Out:
# True

# %% [markdown]
# **if a string contains digits only, it's still not a number**
#
# **Comparing strings against numbers is generally a bad idea**

# %%
print('10' == '010')
print('10' > '010')
print('10' > '8')
print('20' < '8')
print('20' < '80')
# Out:
# False
# True
# False
# True
# True

# %%
'10' == 10
'10' != 10
'10' == 1
'10' != 1
# Out:
# True

# %%
#The only comparisons you can perform with impunity are these symbolized by the == and != operators.
'10' > 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-f9d8317609dd> in <module>()
#       1 #The only comparisons you can perform with impunity are these symbolized by the == and != operators.
# ----> 2 '10' > 10
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# # **.index(), .find(), .rfind(), .sort(), sorted()**

# %% [markdown]
# **The index()** method (it's a method, not a function) searches the sequence from the beginning, in order to find the first element of the value specified in its argument.

# %%
# Demonstrating the index() method:
print("aAbByYzZaA".index("b"))
print("aAbByYzZaA".index("bB"))
print("aAbByYzZaA".index("Z"))
print("aAbByYzZaA".index("A"))
# Out:
# 2
# 2
# 7
# 1

# %% [markdown]
# **The find()** method is similar to index(), which you already know - it looks for a substring and returns the index of first occurrence of this substring, but:
#
# it's safer - it doesn't generate an error for an argument containing a non-existent substring (it returns -1 then)
#
#
# it works with strings only - don't try to apply it to any other sequence.

# %%
# Demonstrating the find() method:
print("Eta".find("ta"))
print("Eta".find("mma"))
# Out:
# 1
# -1

# %% [markdown]
# **Note: don't use find() if you only want to check if a single character occurs within a string - the in operator will be significantly faster.**

# %%
t = 'theta'
print(t.find('eta'))
print(t.find('et'))
print(t.find('the'))
print(t.find('ha'))
# Out:
# 2
# 2
# 0
# -1

# %% [markdown]
# The **second argument** specifies the index at which the search will be started (it doesn't have to fit inside the string).

# %%
print('aakpp'.find('a', 2))
# Out:
# -1

# %%
print('kaapp'.find('a', 2))
# Out:
# 2

# %%
print('kaapp'.find('a', 1000))
# Out:
# -1

# %% [markdown]
# **The 3rd argument** Points to the first index which **won't** be taken into consideration during the search (it's actually the upper limit of the search)

# %%
print('kappa'.find('a', 1, 4))
print('kappa'.find('a', 2, 4))
print('kappa'.find('a', 2, 5))
# Out:
# 1
# -1
# 4

# %% [markdown]
# **rfind()**
# Same as find but search from the right

# %%
# Demonstrating the rfind() method:
print("tau tau tau".rfind("ta"))
print("tau tau tau".rfind("ta", 9))
print("tau tau tau".rfind("ta", 3, 9))
# Out:
# 8
# -1
# 4

# %% [markdown]
# Sorting lists of strings can be done by:
#
# a function named **sorted()**, creating a new, sorted list;
#
# a method named **sort()**, which sorts the list in situ

# %%
# Demonstrating the sorted() function:
first_greek = ['omega', 'alpha', 'pi', 'gamma']
first_greek_2 = sorted(first_greek)

print(first_greek)
print(first_greek_2)

print()

# Demonstrating the sort() method:
second_greek = ['omega', 'alpha', 'pi', 'gamma']
print(second_greek)

second_greek.sort()
print(second_greek)
# Out:
# ['omega', 'alpha', 'pi', 'gamma']
# ['alpha', 'gamma', 'omega', 'pi']
#
# ['omega', 'alpha', 'pi', 'gamma']
# ['alpha', 'gamma', 'omega', 'pi']

# %%
letters = 'xyz'

# %%
list(letters)
# Out:
# ['x', 'y', 'z']

# %%
new_str = letters.sorted()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3224/656337688.py in <module>
# ----> 1 new_str = letters.sorted()
#
# AttributeError: 'str' object has no attribute 'sorted'

# %%
new_str = letters.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3224/2948294626.py in <module>
# ----> 1 new_str = letters.sort()
#
# AttributeError: 'str' object has no attribute 'sort'

# %%
sorted(letters)
# Out:
# ['x', 'y', 'z']

# %% [markdown]
# # **.isxxx(), .join(), .split()**

# %% [markdown]
# **join() method**
#
# it expects one argument as a list; it must be assured that all the list's elements are strings - the method will raise a TypeError exception otherwise;
#
# The string from which the method has been invoked is **used as a separator**, put among the strings;

# %%
# Demonstrating the join() method:
print(",".join(["omicron", "pi", "rho"]))
# Out:
# omicron,pi,rho

# %% [markdown]
# **split()**
#
# splits the string and builds a list of all detected substrings.
#
# The method **assumes** that the substrings are delimited by **whitespaces**
#
# Note: the reverse operation can be performed by the join() method.

# %%
# Demonstrating the split() method:
print("phi       chi\npsi".split())
# Out:
# ['phi', 'chi', 'psi']

# %%
strr = 'omicron,pi,rho'

# %%
strr.split(",")
# Out:
# ['omicron', 'pi', 'rho']

# %% [markdown]
# **1. Some of the methods offered by strings are**:
#
# capitalize() – changes all string letters to capitals;
#
# center() – centers the string inside the field of a known length;
#
# count() – counts the occurrences of a given character;
#
# join() – joins all items of a tuple/list into one string;
#
# lower() – converts all the string's letters into lower-case letters;
#
# lstrip() – removes the white characters from the beginning of the string;
#
# replace() – replaces a given substring with another;
#
# rfind() – finds a substring starting from the end of the string;
#
# rstrip() – removes the trailing white spaces from the end of the string;
#
# split() – splits the string into a substring using a given delimiter;
#
# strip() – removes the leading and trailing white spaces;
#
# swapcase() – swaps the letters' cases (lower to upper and vice versa)
#
# title() – makes the first letter in each word upper-case;
#
# upper() – converts all the string's letter into upper-case letters.
#
# **2. String content can be determined using the following methods (all of them return Boolean values)**:
#
# endswith() – does the string end with a given substring?
#
# isalnum() – does the string consist only of letters and digits?
#
# isalpha() – does the string consist only of letters?
#
# islower() – does the string consists only of lower-case letters?
#
# isspace() – does the string consists only of white spaces?
#
# isupper() – does the string consists only of upper-case letters?
#
# startswith() – does the string begin with a given substring?
