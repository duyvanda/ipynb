# %%
# import variants; advanced qualifiying for nested modules

# %%
# dir(); sys.path variable

# %%
# math: ceil(), floor(), trunc(), factorial() giai thua 2! 3!, hypot(), sqrt();

# %% [markdown]
# # The essentials of modules and packages

# %% [markdown]
# A **namespace** is a space in which some names exist and the names don’t conflict with each other
#
# (i.e., there are no two objects with the same name)

# %% [markdown]
# **A module** is a file containing Python definitions and statements which can be imported
#
# and used by another Python code.
#
# **A package** is a way of structuring a module’s namespace by using dotted module names.
#
# It can be said that the module is a hierarchical collection of modules.
#
# **To import** a module and to make its content available, the import directive is used.
#
# If there is a module named **mod** which contains a function named **fun()**.
#
# The following import forms can be used:
#
# -import mod; mod.fun()
#
# -from mod import fun; fun()
#
# -from mod import *; fun()

# %% [markdown]
# **dir()** is a built-in function, it can be used to obtain an alphabetically sorted list which
#
# contains all entity names available in the module

# %% [markdown]
# **How Python deals with modules**
#
#     A)
#
# When a certain module is imported for the first time, Python convert its contents into a
#
# semi-compiled code which can be used to execute module functions faster.
#
#
#     B)
#
# The semi-compiled files are placed in the directory named __pycache__, located in the
#
# same directory in which the source module exists.
#
#
#     C)
#
# If the source file of a module is named mod.py, its semi-compiled counterpart will be
#
# named mod.cpython-xy.pyc where x and y are numbers derived from your Python’s version number.
#
#
#     D)
#
# There is a special built-in variable named __name__ whose value:
#
# • is set to “__main__” when the module is run as a standalone code;
#
# • is set to the source file’s name (excluding .py) when the file is imported as a module.
#
# Example: the snippet below can be used to determine the context in which the source file is used
#
# if __name__ == “__main__”:
#
#     print(“Run as a program”)
#
# else:
#
#     print(“Imported as a module”)
#
#
#     E)
#
# If the name of any module entities starts with **_ or __**, the entity should be treated as
#
# private and not used outside the module.
#
#
#
#     F)
#
# The very first line of a Python source file can start with #!, in which case it’s called the
#
# shabang, shebang, hashbang, poundbang, or even the hashpling line. From Python’s
#
# point of view, it’s just a comment.
#
# For Unix and Unix-like OSs (including MacOS) such a line instructs the OS on how to execute the contents of the file (in other words, what program needs to be launched to interpret the text). This is what it may look like in some environments:
#
#
# #! /usr/bin/env python3
#
#
#     G)
#
# The module of the name given in the import directive is searched inside directories
#
# whose names are listed in the sys.path variable (it’s a list strings). The first element of
#
# the list is the directory in which the code that performs the import resides. The user is
#
# allowed to modify the sys.path contents in order to limit or extend the range of
#
# directories being searched through

# %% [markdown]
# **Packages**
#
#     A)
#
# **Package** is a group of Python source files deployed in a certain subtree of the file system.
#
# Let’s assume that the following set of files and directories exists:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#     B)
#
# A source file named __init__.py located in certain place of the directory structure
#
# defines the root of the package, in other words, it determines the location and name of
#
# the package. If the file is not empty, its contents will be executed when any of the
#
# package’s modules is imported, so it may be used to initialize the package’s state.
#
#     C)
#
# If we assume that the package directory is listed in the sys.path variable, it’s guaranteed
#
# that it will be searched through when Python is looking for modules.
#
# If you want to invoke the turn_on() function provided by the gearbox.py module located inside the package
#
# *>>> import package.gearbox*
#
# *>>> package.gearbox.turn_on()*
#
# *>>> from package.gearnox import turn_on*
#
# *>>> turn_on()*
#
# *>>> from package.gearnox import asterisk*
#
# *>>> turn_on()*

# %% [markdown]
#     D)
#
# Executing the imports will provoke Python to create
#
# __pycache__ directories located under the package directories, and
#
# will fill them with .pyc files, which contain semi-compiled code of the modules
#
# imported, In effect, the subtree contents structure will look like this:
#
# ![image.png](data:image/png;base64,...)

# %%
from math import *

# %%
x = 1.1
print(floor(x))
print(ceil(x))
print(trunc(x))
# Out:
# 1
# 2
# 1

# %%
x = -1.5
print(floor(x))
print(ceil(x))
print(trunc(x))
# Out:
# -2
# -1
# -1

# %%
x = -1.1
print(floor(x))
print(ceil(x))
print(trunc(x))
# Out:
# -2
# -1
# -1

# %%
import math 
  
x = 5
y = 15
z = 8
  
print ("The factorial of 5 is : ", math.factorial(x))
print ("The factorial of 15 is : ", math.factorial(y))
print ("The factorial of 8 is : ", math.factorial(z))
# Out:
# The factorial of 5 is :  120
# The factorial of 15 is :  1307674368000
# The factorial of 8 is :  40320

# %%
# factorial
# Throws ValueError if x is not integer

# %%
hypot(3,4)
# Out:
# 5.0

# %%
sqrt(3*3+4*4)
# Out:
# 5.0

# %%
# random: random(), seed(), choice(), sample()

# %%
# Python random.random() function generate random floating numbers between 0 and 1.

# %%
from random import random

# %%
print(random())
# Out:
# 0.4955781937832351

# %%
from random import randrange

# %%
# (start,stop,step), all below are equivalent
print(randrange(100))
print(randrange(0,100))
print(randrange(0,100,1))
# Out:
# 74
# 71
# 20

# %%
import random

# %%
# random.seed()

# %%
# importing random module
import random
  
random.seed(3)
  
# print a random number between 1 and 1000.
print(random.randint(1, 1000))
  
# if you want to get the same random number again then,
random.seed(3) 
print(random.randint(1, 1000))
  
# If seed function is not used
  
# Gives totally unpredictable responses.
print(random.randint(1, 1000))
# Out:
# 244
# 244
# 607

# %%
# choice()

# %%
# random.choice(sequence)
# Parameters: 
# sequence is a mandatory parameter that
# can be a list, tuple, or string.
# Returns:  
# The choice() returns a random item.

# %%
# Python3 program to demonstrate the use of
# choice() method 
  
# import random 
import random
  
# prints a random value from the list
list1 = [1, 2, 3, 4, 5, 6] 
print(random.choice(list1))
  
# prints a random item from the string 
string = "striver" 
print(random.choice(string))
# Out:
# 5
# t

# %%
# CHOICES

# %%
import random

mylist = ["geeks", "for", "python"]

print(random.choices(mylist))
# Out:
# ['geeks']

# %%
import random

mylist = ["geeks", "for", "python"]

print(random.choices(mylist, weights = [10, 1, 1], k = 5))
# Out:
# ['geeks', 'geeks', 'geeks', 'geeks', 'geeks']

# %% [markdown]
# Syntax : random.choices(sequence, weights=None, cum_weights=None, k=1)
#
# Parameters :
# 1. sequence is a mandatory parameter that can be a list, tuple, or string.
# 2. weights is an optional parameter which is used to weigh the possibility for each value.
# 3. cum_weights is an optional parameter which is used to weigh the possibility for each value but in this the possibility is accumulated
# 4. k is an optional parameter that is used to define the length of the returned list.

# %%
from platform import *

# %%
platform()
# Out:
# 'Windows-10-10.0.19043-SP0'

# %% [markdown]
# **aliased** → when set to True (or any non-zero value) it may cause the function to present the alternative underlying layer names instead of the common ones;
#
# **terse** → when set to True (or any non-zero value) it may convince the function to present a briefer form of the result (if possible)

# %%
platform(aliased = False, terse = False)
# Out:
# 'Windows-10-10.0.19043-SP0'

# %%
print(platform())
print(platform(1))
print(platform(0, 1))
# Out:
# Windows-10-10.0.19043-SP0
# Windows-10-10.0.19043-SP0
# Windows-10

# %%
import platform
platform.platform(aliased=0, terse=0)
# Out:
# 'Windows-10-10.0.19043-SP0'

# %%
machine()
# Out:
# 'AMD64'

# %%
processor()
# Out:
# 'Intel64 Family 6 Model 140 Stepping 1, GenuineIntel'

# %%
system()
# Out:
# 'Windows'

# %%
version()
# Out:
# '10.0.19043'

# %%
python_implementation()
# Out:
# 'CPython'

# %%
python_version_tuple()
# Out:
# ('3', '9', '6')

# %%
from platform import python_implementation, python_version_tuple

print(python_implementation())

for atr in python_version_tuple():
    print(atr)
# Out:
# CPython
# 3
# 9
# 6

# %%
# from .module import suml
