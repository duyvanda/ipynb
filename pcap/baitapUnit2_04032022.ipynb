# %% [markdown]
# Question 1: Write a program to find out the largest and smallest word in the string "This is an umbrella".
#
# Question 2: Write a program to check if a given string is a Palindrome. A palindrome reads the same from the front and back e.g.- aba, ccaacc, mom, etc.
#
# Question 3: Write down the names of 10 of your friends in a list and then sort those in alphabetically ascending order.
#
# Question 4: Write a program to make a new string with the word "the" deleted in the sentence "This is the lion in the cage".
#
# Question 5: Write a program to check if the two strings entered by the user are anagrams or not. Two words are said to be anagrams if the letters of one word can be rearranged to form the other word. For example, jaxa and ajax are anagrams of each other.
#
# Question 6: Write a program that takes your full name as input and displays the abbreviations of the first and middle names except for the last name which is displayed as it is. For example, if your name is Robert Brett Roser, then the output should be R.B.Roser.
#
# Question 7: Write a program to make a new string with all the consonants deleted from the string "Hello, have a good day".
#
# Question 8: Write a program to find the length of the string "refrigerator" without using len function.
#
# Question 9: Write a python program to read a date (dd-mm-yyyy) and print the month name according to the month number.
#
# Question 10: Write a python program to read an IP address from stdin and check whether it is valid or not
#
# '''
#
# Interface ethernet0 is up
#
# Interface ethernet1 is down
#
# Interface serial0 is down
#
# Interface serial1 is up '''
#
# Question 11: Write a python program find the number of characters present in a string (without using len())
#
# Question 12: Write a python program to reverse a string without using builtin methods

# %%
#Q1
st="This is an umbrella"
string_lst = st.split()

# %%
w0 = [w[0] for w in string_lst]

# %%
w1 = [ord(l) for l in w0]

# %%
lst = [ x for x in string_lst if chr(max(w1)) == x[0] ]

# %%
for x in string_lst:
  if chr(max(w1)) == x[0] : print(x)
# Out:
# umbrella

# %%
print(lst)
# Out:
# ['umbrella']

# %%
#Q2

# %%
def isPalindrome(s):
    return s == s[::-1]

# %%
s = "vmalayalam"

# %%
# s[0:-1]

# %%
# Driver code
s = "malayalam"
ans = isPalindrome(s)
 
if ans:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#Q3
first_greek = ['omega', 'alpha', 'pi', 'gamma']
first_greek_2 = sorted(first_greek)

print(first_greek)
print(first_greek_2)
# Out:
# ['omega', 'alpha', 'pi', 'gamma']
# ['alpha', 'gamma', 'omega', 'pi']

# %%
#Q4
sentence="This is the lion in the cage"

# %%
sentence.replace("the", "").replace("  "," ")
# Out:
# 'This is lion in cage'

# %%
#Q5

# %%
def check(s1, s2):
     
    # the sorted strings are checked
    if(sorted(s1)== sorted(s2)):
        print("The strings are anagrams.")
    else:
        print("The strings aren't anagrams.")        
         
# driver code 
s1 ="listen"
s2 ="silent"
check(s1, s2)
# Out:
# The strings are anagrams.

# %%
#Q6

# python program to print initials of a name 
def name(s):
  
    # split the string into a list 
    l = s.split()
    new = ""
  
    # traverse in the list 
    for i in range(len(l)-1):
        s = l[i]
          
        # adds the capital first character 
        new += (s[0].upper()+'.')
          
    # l[-1] gives last item of list l. We
    # use title to print first character in
    # capital.
    new += l[-1].title()
      
    return new 
      
# Driver code            
s ="mohandas karamchand gandhi" 
print(name(s))
# Out:
# M.K.Gandhi

# %%
#Q7
# initializing string
test_str = "Gfg is best for geeks"
 
# printing original string
print("The original string is : " + test_str)
 
# Remove all consonants from string
# Using list comprehension
res = "".join([chr for chr in test_str if chr in "aeiouAEIOU"])
 
# printing result
print("String after consonants removal : " + str(res))
# Out:
# The original string is : Gfg is best for geeks
# String after consonants removal : ieoee

# %%
#Q8
a = "refrigerator"
count = 0
for i in a:
  count = count+1
print(count)
# Out:
# 12

# %%
#Q9 SKIP
#Q10 SKIP

# %%
#Q11 = Q8
#Q12 = Q2

# %%
Huynh Nguyen Tan7:58 PM
["www.zframez.com", "www.wikipedia.org", "www.asp.net", "www.abcd.in"]
Write a python program to print website suffixes (com , org , net ,in) from this list
Write a python program to remove repeated elements from a given list without using built-in methods
Huynh Nguyen Tan7:59 PM
Write a python program to find number of occurrences of given number with out using built-in methods
# Out:
#   File "<ipython-input-29-27717a59e15b>", line 1
#     Huynh Nguyen Tan7:58 PM
#                ^
# SyntaxError: invalid syntax

# %%
#Type your answer below (pick the correct line).

a=5
b=0
try:
    result=a/b
except ZeroDivisionError:

print(result)
# Out:
#   File "<ipython-input-30-46fd69cfbf05>", line 9
#     print(result)
#         ^
# IndentationError: expected an indented block

# %%
#Type your code here.

a = [1, 3, 5]
try:
    a.get()
except:

print(a)
Huynh Nguyen Tan8:02 PM
get() is not a list method. Place pass keyword to the right line so that program doesn't throw an error.
# Out:
#   File "<ipython-input-31-6818788548e1>", line 8
#     print(a)
#         ^
# IndentationError: expected an indented block

# %%
You're going to write an interactive calculator! User input is assumed to be a formula that consist of a number, an operator (at least + and -), and another number, separated by white space (e.g. 1 + 1). Split user input using str.split(), and check whether the resulting list is valid:

If the input does not consist of 3 elements, raise a FormulaError, which is a custom Exception.
Try to convert the first and third input to a float (like so: float_value = float(str_value)). Catch any ValueError 

>>> 1 + 1
2.0
>>> 3.2 - 1.5
1.7000000000000002
>>> quit
# Out:
#   File "<ipython-input-32-09d3996ed2dd>", line 1
#     You're going to write an interactive calculator! User input is assumed to be a formula that consist of a number, an operator (at least + and -), and another number, separated by white space (e.g. 1 + 1). Split user input using str.split(), and check whether the resulting list is valid:
#                                                                                                                                                                                                                                                                                                   ^
# SyntaxError: EOL while scanning string literal
