# %%
# 1. import tat ca ham co trong module toan hoc de thuc hien cac yeu cau sau

# tinh can bac 2 cua 16
# tim luy thua cua 6 power input()

from math import *

print(sqrt(16))

x = input()

print(pow(6, int(x)))
# Out:
# 4.0
# 46656.0

# %%
# Out put list cac duong dan co trong module system
import sys

for i in sys.path:
    print(i)
# Out:
# d:\data_sale\ipython_file\pcap
# C:\Users\DELL\AppData\Local\Programs\Python\Python39\python39.zip
# C:\Users\DELL\AppData\Local\Programs\Python\Python39\DLLs
# C:\Users\DELL\AppData\Local\Programs\Python\Python39\lib
# C:\Users\DELL\AppData\Local\Programs\Python\Python39
# d:\data_sale\venv
#
# d:\data_sale\venv\lib\site-packages
# d:\data_sale\venv\lib\site-packages\win32
# d:\data_sale\venv\lib\site-packages\win32\lib
# d:\data_sale\venv\lib\site-packages\Pythonwin
# d:\data_sale\venv\lib\site-packages\IPython\extensions
# C:\Users\DELL\.ipython
# C:\Users\DELL\AppData\Roaming\Python\Python39\site-packages

# %%
# dung math de check voi so do bat ky cua 1 tam giac tu input() no co la tam giac vuong hay khong?
# Dat ten cua ham mac dinh thanh 1 ten moi ma cac ban de nho

from math import sqrt
print("Input lengths of shorter triangle sides:")
a = float(input("a: "))
b = float(input("b: "))
c = float(input("b: "))
x = sqrt(a**2 + b**2)
print("right triangle") if c == x else print("not right triangle")
# Out:
# Input lengths of shorter triangle sides:
# right triangle

# %%
# CO THE XAI HAM HYPOT math.hypot

# %%
# Output ngay thang nam mac dinh cua may tinh
from datetime import datetime
print(datetime.now().time())
# Out:
# 14:23:19.352149

# %%
# from datetime import time
# print(time.time)

# %%
# cho 1 bang du lieu chua cac thong tin cua 1 sv bao gom:
# ho va ten
# ngay thang nam sinh
# tuoi
# dia chi tinh theo tinh
# Hay check 1 du lieu bat ky co ton tai trong file luu tru hay khong

# %%
with open('/content/drive/MyDrive/ttsv.txt') as f:
    datafile = (f.readlines())

# %%
substring = input("What")
# Out:
# WhatPham Le

# %%
for i in datafile:
    if substring in i:
        print(i)
# Out:
# Pham Le, 01/01/12, 10, 7 Thanh Thai

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
for i in datafile:
    if substring in i:
        print(i)
# Out:
# Pham Le, 01/01/12, 10, 7 Thanh Thai

# %%
import os

# %%
# ls

# %%
os.chdir('/content/drive/MyDrive')
