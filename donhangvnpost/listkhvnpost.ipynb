# %%
from utils.df_handle import *
from requests.structures import CaseInsensitiveDict
import requests
import json, pickle
# Out:
# Default bq project:  spatial-vision-343005.biteam

# %%
df = pd.read_excel("ListKhVNP_Duy_23122022_P2.xlsx", sheet_name="DataVNpost")

# %%
df.columns = lower_col(df)

# %%
df.columns = cleancols(df)

# %%
df.columns
# Out:
# Index(['makhdms', 'diachikh', 'codetinhkh', 'codequanhuyen', 'codephuongxa',
#        'sodienthoai', 'tenkhachhang'],
#       dtype='object')

# %%
df.codetinhkh = df.codetinhkh.astype(str)
df.codequanhuyen = df.codequanhuyen.astype(str)
df.codephuongxa = df.codephuongxa.astype(str)

# %%
df.to_dict(orient="records")
# Out:
# [{'makhdms': 'N05702039',
#   'diachikh': 'Số 186 Trần Hưng Đạo   ',
#   'codetinhkh': '62',
#   'codequanhuyen': '6210',
#   'codephuongxa': '62106',
#   'sodienthoai': '0836906686',
#   'tenkhachhang': 'NT Phòng Khám Thiên Anh - Phú Yên'},
#  {'makhdms': 'N0110607',
#   'diachikh': '.   ',
#   'codetinhkh': '51',
#   'codequanhuyen': '5122',
#   'codephuongxa': '51221',
#   'sodienthoai': '23',
#   'tenkhachhang': 'BV ĐK KV Bắc Quảng Bình - Quảng Bình'},
#  {'makhdms': 'P5506-0024',
#   'diachikh': 'Khuôn viên Bệnh Viện Bắc Quảng Bình   ',
#   'codetinhkh': '51',
#   'codequanhuyen': '5122',
#   'codephuongxa': '51221',
#   'sodienthoai': '0984278292',
#   'tenkhachhang': 'NT Thiết Lới (NT BV Bắc Quảng Bình) - Ba Đồn - Quảng Bình'},
#  {'makhdms': 'N0110610',
#   'diachikh': 'Tiểu khu 9   ',
#   'codetinhkh': '51',
#   'codequanhuyen': '5115',
#   'codephuongxa': '51150',
#   'sodienthoai': 'xxx',
#   'tenkhachhang': 'BV ĐK Huyện Bố Trạch - Quảng Bình'},
#  {'makhdms': '000529',
# ...
