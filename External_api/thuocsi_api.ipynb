# %%
from utils.df_handle import *
# Out:
# Default bq project:  spatial-vision-343005.biteam

# %%
import requests
from requests.structures import CaseInsensitiveDict

# %%
import json

# %%
url = "https://thuocsi.vn/backend/marketplace/product/v2/search/fuzzy"
headers = CaseInsensitiveDict()
headers['Authorization'] = 'Bearer Q1VTVE9NRVIvMDc4NDY3MjY3ODpGNVQzQkxKbUNCajNYY0ZoMmlnd1o2dGJlcEg4UHFGWVg0Vmx5dVR1cm1tOWhmdGc='
headers['Connection'] = 'keep-alive'
headers['Content-Type'] = 'application/json'
# headers
headers['Origin'] = 'https://thuocsi.vn'
# headers['Referer'] = 'https://thuocsi.vn/products?q=medoral&searchType=1'
headers['User-Agent'] = 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Mobile Safari/537.36'

raw_data = {"q":"medoral","searchType":"1","text":"medoral","offset":0,"limit":30,"getTotal":True,"filter":{},"sort":"","isAvailable":False,"searchStrategy":{"text":True,"keyword":True}}

resp = requests.post(url, headers=headers, json=raw_data)
resp.json()
# with open('filename_10_07.xlsx', 'wb') as output:
#   output.write(resp.content)
# Out:
# {'status': 'OK',
#  'data': [{'isAvailable': True,
#    'product': {'atc2Code': '22U1Y7G',
#     'atc3Code': '33PABCL',
#     'categoryCodes': ['9TT61PGEQ1', 'UTT61PGEQ1'],
#     'categoryInCharge': 64044,
#     'categoryManagement': 'BRANDNAME',
#     'code': 'MER-MED-001',
#     'createdTime': '2021-05-04T04:50:54.237Z',
#     'dosageForm': 'Sirô/Hỗn dịch',
#     'efficacyCodes': ['CR2AXH'],
#     'height': 145,
#     'imageUrls': ['https://storage.googleapis.com/thuocsi-live/images/name5660-57225248.png'],
#     'ingredients': [{'ingredientCode': 'K7Q1PG', 'volume': '0.2%'}],
#     'isCombo': False,
#     'isFragile': True,
#     'isIngredientSpecial': False,
#     'isPrescription': False,
#     'lastUpdatedTime': '2022-06-24T10:35:44.269Z',
#     'length': 65,
#     'mainCategoryCode': '4FW961',
#     'manufacturerCode': 'WA2AXHR2AX',
#     'name': 'medoral merap (c/250ml)',
#     'origin': 'VN',
#     'owner': 'MEDX',
#     'productID': 6783,
# ...
