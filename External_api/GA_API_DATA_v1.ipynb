# %%
from utils.df_handle import *

# %%
ga_pivot_report(lst_dm=['pageTitle','deviceCategory','date'], lst_mt=['activeUsers','newUsers'], start_date="2022-04-01", end_date="today",csv_path="D:/data_sale/ipython_file/External_api/")

# %%
pd.read_csv("20220418data_dimension.csv", names=["tenbaocao","device","date","uname"])
# Out:
#                              tenbaocao   device      date  uname
# 0                View Công Nợ v2 (MDS)   mobile  20220415    NaN
# 1                 View Công Nợ v2(Sup)  desktop  20220416    NaN
# 2                 View Công Nợ v2(Dir)  desktop  20220401    NaN
# 3                 View Công Nợ (Daily)  desktop  20220416    NaN
# 4                View Công Nợ v2 (MDS)   mobile  20220416    NaN
# 5                 View Công Nợ v2(Dir)  desktop  20220413    NaN
# 6                 View Công Nợ v2(Dir)  desktop  20220415    NaN
# 7                View Công Nợ v2 (MDS)  desktop  20220416    NaN
# 8                View Công Nợ v2 (MDS)   mobile  20220417    NaN
# 9                 View Công Nợ v2(Dir)  desktop  20220404    NaN
# 10                View Công Nợ v2(Dir)  desktop  20220408    NaN
# 11                View Công Nợ v2(Dir)  desktop  20220414    NaN
# 12                View Công Nợ v2(Dir)  desktop  20220416    NaN
# ...
