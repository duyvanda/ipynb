# %%
import requests

# %%
url = 'https://dms.phanam.com.vn/PhaNamAPI_Token/api/v1/MasterData?id=GetPayment'

# %%
headers = {"Parameter": '{"DateGetData":"2021-07-25"}', "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1bmlxdWVfbmFtZSI6IjEiLCJuYmYiOjE2MTQ5MjY1NTIsImV4cCI6MTY0NjQ2MjU1MiwiaWF0IjoxNjE0OTI2NTUyfQ.Xx65VfXGJasSYL0diWvV2Q0Ohan6b4Zz1GW48C2tGzE", "Connection": "keep-alive"}
r = requests.get(url, headers=headers)

# %%
# r.encoding
# Out:
# Running cells with 'Python 3.9.10 64-bit (windows store)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'C:/Users/DELL/AppData/Local/Microsoft/WindowsApps/python3.9.exe -m pip install ipykernel -U --user --force-reinstall'
