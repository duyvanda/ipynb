# %%
from utils.df_handle import *
import argparse
import os
from google.oauth2 import service_account
import googleapiclient.discovery
# Out:
# Default bq project:  spatial-vision-343005.biteam

# %%
lst = \
[
# MDS SUP
'dailammoc0888@gmail.com',
'hoangmanh3983@gmail.com',
'tringuyen0089@gmail.com',
'thaibao050579@gmail.com',
'tunglamanh6789@gmail.com',
'hoaphanam2022@gmail.com',
'dannyitlk@gmail.com',
'nguyenhoangnguyen1611@gmail.com',
'thang111982@gmail.com',
'minhtd3@gmail.com',
'phankhai0105@gmail.com',
# 'dangtuyethanh@gmail.com',
'thanglt0906@gmail.com',
'thanh37np@gmail.com',
'daotanhieukt@gmail.com',
'dannyitlk@gmail.com',
]

# %%
lst_sc = \
[
# MDS SUP
'fullhouse.qnvh@gmail.com',
'tamkt1984@gmail.com'
]

# %%
lst_ceophanam = \
[
# MDS SUP
'trangnn79@gmail.com'
]

# %%
# credentials = service_account.Credentials.from_service_account_file(
#     filename=os.environ['GOOGLE_APPLICATION_CREDENTIALS'],
#     scopes=['https://www.googleapis.com/auth/cloud-platform'])
# service = googleapiclient.discovery.build(
#     'iam', 'v1', credentials=credentials)

# %%
# def view_grantable_roles(full_resource_name="//iam.googleapis.com/projects/spatial-vision-343005/serviceAccounts/bigquery@spatial-vision-343005.iam.gserviceaccount.com"):
#     roles = service.roles().queryGrantableRoles(body={
#         'fullResourceName': full_resource_name
#     }).execute()

#     for role in roles['roles']:
#         if 'title' in role:
#             print('Title: ' + role['title'])
#         print('Name: ' + role['name'])
#         if 'description' in role:
#             print('Description: ' + role['description'])
#         print(' ')
# [END iam_view_grantable_roles]

# %%
# view_grantable_roles()

# %%
# roles = service.roles().list(
#     parent='projects/' + pjt).execute()['roles']
# for role in roles:
#     print(role['name'])

# %%
credentials = service_account.Credentials.from_service_account_file(
    filename=os.environ['GOOGLE_APPLICATION_CREDENTIALS'],
    scopes=['https://www.googleapis.com/auth/cloud-platform'])
service = googleapiclient.discovery.build(
    'cloudresourcemanager', 'v1', credentials=credentials)

# %%
# policy = (
#     service.projects()
#     .getIamPolicy(
#         resource=pjt,
#         body={"options": {"requestedPolicyVersion": 1}},
#     )
#     .execute()
# )
# print(policy)

# %%
# policy['bindings']

# %%
lab_lst = \
[
'thinhduoc@gmail.com',
'namnh608@gmail.com',
'phungxuanle1987@gmail.com',
'hungcv603@gmail.com',
'phamminhthu294@gmail.com',
'acebis225@gmail.com'
]

# %%
import google.auth

# %%
def initialize_service():
    """Initializes a Cloud Resource Manager service."""

    credentials, _ = google.auth.default(
        scopes=["https://www.googleapis.com/auth/cloud-platform"]
    )
    crm_service = googleapiclient.discovery.build(
        "cloudresourcemanager", "v1", credentials=credentials
    )
    return crm_service

# %%
role = "projects/spatial-vision-343005/roles/CustomBigQueryJobUser"

# %%
def set_policy(crm_service, project_id, policy):
    """Sets IAM policy for a project."""

    policy = (
        crm_service.projects()
        .setIamPolicy(resource=project_id, body={"policy": policy})
        .execute()
    )
    return policy

# %%
def get_policy(crm_service, project_id, version=1):
    """Gets IAM policy for a project."""

    policy = (
        crm_service.projects()
        .getIamPolicy(
            resource=project_id,
            body={"options": {"requestedPolicyVersion": version}},
        )
        .execute()
    )
    return policy

# %%
# role = "roles/bigquery.jobUser"

# %%
def modify_policy_add_role(crm_service, project_id, role, member):
    """Adds a new role binding to a policy."""

    policy = get_policy(crm_service, project_id)

    binding = None
    for b in policy["bindings"]:
        if b["role"] == role:
            binding = b
            break
    if binding is not None:
        binding["members"].append(member)
    else:
        binding = {"role": role, "members": [member]}
        policy["bindings"].append(binding)

    set_policy(crm_service, project_id, policy)

# %%
# for i in lst:
#     print(i)

# %%
for i in lst_ceophanam:
    modify_policy_add_role(crm_service=service, project_id="spatial-vision-343005", role=role, member=f"user:{i}")

# %%
def modify_policy_remove_member(crm_service, project_id, role, member):
    """Removes a  member from a role binding."""

    policy = get_policy(crm_service, project_id)

    binding = next(b for b in policy["bindings"] if b["role"] == role)
    if "members" in binding and member in binding["members"]:
        binding["members"].remove(member)

    set_policy(crm_service, project_id, policy)
    print(member)

# %%
for i in lst:
    modify_policy_remove_member(crm_service=service, project_id="spatial-vision-343005", role=role, member=f"user:{i}")
# Out:
# user:203hangdtt@gmail.com
# user:Acebis225@gmail.com
# user:aiphi265@gmail.com
# user:andykhoailang@gmail.com
# user:anhcu.king@gmail.com
# user:anhk3c2013@gmail.com
# user:anhkhoa0887st@gmail.com
# user:anhtam.sn96@gmail.com
# user:anhtranit1994@gmail.com
# user:AnhTuanCg2006@gmail.com
# user:aniethanhlieu@gmail.com
# user:banhtumy90@gmail.com
# user:bichtien201091@gmail.com
# user:btpuyen94@gmail.com
# user:buitrungnguyen298@gmail.com
# user:camnguyen1781990@gmail.com
# user:camtu.phanam@gmail.com
# user:canh.oseven@gmail.com
# user:caothiminhhien@gmail.com
# user:chauld81@gmail.com
# user:chulong85vt@gmail.com
# user:ctphanamkhanhhoa@gmail.com
# user:Cuong.naga.vn@gmail.com
# user:cuonghv0702@gmail.com
# user:cuongpham20031991@gmail.com
# user:cuongtnt1987@gmail.com
# user:D.HOOFU95@gmail.com
# user:dannguyen7892@gmail.com
# user:daothimanhhienetc@gmail.com
# user:datbmw2798@gmail.com
# user:dattienhung@gmail.com
# user:diadang1808@gmail.com
# user:dieptrinhtran9898@gmail.com
# ...

# %%
modify_policy_remove_member(crm_service=service, project_id="spatial-vision-343005", role=role, member="user:nhanvt92@gmail.com")

# %%
def modify_policy_add_role(crm_service, project_id, role, member):
    """Adds a new role binding to a policy."""

    policy = get_policy(crm_service, project_id)

    binding = None
    for b in policy["bindings"]:
        if b["role"] == role:
            binding = b
            break
    if binding is not None:
        binding["members"].append(member)
    else:
        binding = {"role": role, "members": [member]}
        policy["bindings"].append(binding)

    set_policy(crm_service, project_id, policy)
modify_policy_add_role(crm_service=service, project_id="spatial-vision-343005", role=role, member="user:vanquangduy@gmail.com")

# %%
get_policy(crm_service=service, project_id="spatial-vision-343005",version=1)
# Out:
# {'version': 1,
#  'etag': 'BwXlZ60d8p4=',
#  'bindings': [{'role': 'projects/spatial-vision-343005/roles/CustomBigQueryJobUser',
#    'members': ['user:dangtuyethanh@gmail.com', 'user:nhoxngoxbmt@gmail.com']},
#   {'role': 'roles/artifactregistry.serviceAgent',
#    'members': ['serviceAccount:service-216440415413@gcp-sa-artifactregistry.iam.gserviceaccount.com']},
#   {'role': 'roles/bigquery.admin',
#    'members': ['serviceAccount:bigquery@spatial-vision-343005.iam.gserviceaccount.com',
#     'user:bimerap.main@gmail.com']},
#   {'role': 'roles/bigquery.jobUser',
#    'members': ['user:nhanvt92@gmail.com', 'user:vanquangduy@gmail.com']},
#   {'role': 'roles/bigquery.user',
#    'members': ['user:phuonght.merap@gmail.com']},
#   {'role': 'roles/bigquerydatatransfer.serviceAgent',
#    'members': ['serviceAccount:service-216440415413@gcp-sa-bigquerydatatransfer.iam.gserviceaccount.com']},
#   {'role': 'roles/cloudbuild.builds.builder',
# ...

# %%
def modify_policy_add_member(policy, member, role="roles/bigquery.jobUser"):
    """Adds a new member to a role binding."""

    binding = next(b for b in policy["bindings"] if b["role"] == role)
    binding["members"].append(member)
    print(binding)
    return policy

# %%
modify_policy_add_member(policy, "vanquangduy@gmail.com")
# Out:
# {'role': 'roles/bigquery.jobUser', 'members': ['user:nhanvt92@gmail.com', 'vanquangduy@gmail.com']}
# {'version': 1,
#  'etag': 'BwXlVos9VTU=',
#  'bindings': [{'role': 'projects/spatial-vision-343005/roles/CustomBigQueryJobUser',
#    'members': ['user:dangtuyethanh@gmail.com']},
#   {'role': 'roles/artifactregistry.serviceAgent',
#    'members': ['serviceAccount:service-216440415413@gcp-sa-artifactregistry.iam.gserviceaccount.com']},
#   {'role': 'roles/bigquery.admin',
#    'members': ['serviceAccount:bigquery@spatial-vision-343005.iam.gserviceaccount.com',
#     'user:bimerap.main@gmail.com']},
#   {'role': 'roles/bigquery.jobUser',
#    'members': ['user:nhanvt92@gmail.com', 'vanquangduy@gmail.com']},
#   {'role': 'roles/bigquery.user',
#    'members': ['user:phuonght.merap@gmail.com']},
#   {'role': 'roles/bigquerydatatransfer.serviceAgent',
#    'members': ['serviceAccount:service-216440415413@gcp-sa-bigquerydatatransfer.iam.gserviceaccount.com']},
# ...

# %%
from utils.df_handle import *
import argparse
import os
from google.oauth2 import service_account
import googleapiclient.discovery

# %%
# from google.cloud import bigquery

# Construct a BigQuery client object.
client = get_bq_client()

datasets = list(client.list_datasets())  # Make an API request.
project = client.project

if datasets:
    print("Datasets in project {}:".format(project))
    for dataset in datasets:
        print("\t{}".format(dataset.dataset_id))
else:
    print("{} project does not contain any datasets.".format(project))
# Out:
# Datasets in project spatial-vision-343005:
# 	analytics_304931682
# 	biteam
# 	bq_biengine_sink_ver2
# 	bq_log_sink
# 	p_test
# 	report_tracking
# 	sales
# 	view_mapping
# 	view_report

# %%
def modify_entries_add_member(entity_id):
    dataset_id = "spatial-vision-343005.report_tracking"
    entity_id = entity_id
    # from google.cloud.bigquery.enums import EntityTypes
    entity_type = "userByEmail"
    role = "READER"
    dataset = client.get_dataset(dataset_id)  # Make an API request.

    entries = list(dataset.access_entries)
    entries
    # add access
    entries.append(
        bigquery.AccessEntry(
            role=role,
            entity_type=entity_type,
            entity_id=entity_id,
        )
    )
    dataset.access_entries = entries
    dataset = client.update_dataset(dataset, ["access_entries"])  # Make an API request.

# %%
for i in lst_ceophanam:
    modify_entries_add_member(i)
full_dataset_id = "{}.{}".format(dataset.project, dataset.dataset_id)
print(
    "Updated dataset '{}' with modified user permissions.".format(full_dataset_id)
)
# Out:
# Updated dataset 'spatial-vision-343005.view_report' with modified user permissions.

# %%
#remove access

# %%
def modify_entries_remove_member(entity_id):
    dataset_id = "spatial-vision-343005.report_tracking"
    entity_id = entity_id
    # from google.cloud.bigquery.enums import EntityTypes
    entity_type = "userByEmail"
    role = "READER"
    dataset = client.get_dataset(dataset_id)  # Make an API request.

    entries = list(dataset.access_entries)
    # entries
    dataset.access_entries = [entry for entry in entries if entry.entity_id != entity_id]
    dataset = client.update_dataset(dataset, ["access_entries"])  # Make an API request.

# %%
for i in lst:
    modify_entries_remove_member(i)

# %%
# dataset.access_entries = [entry for entry in entries if entry.entity_id != entity_id]

# %%
lst = \
[
'203hangdtt@gmail.com',
'Acebis225@gmail.com',
'aiphi265@gmail.com',
'andykhoailang@gmail.com',
'anhcu.king@gmail.com',
'anhk3c2013@gmail.com',
'anhkhoa0887st@gmail.com',
'anhtam.sn96@gmail.com',
'anhtranit1994@gmail.com',
'AnhTuanCg2006@gmail.com',
'aniethanhlieu@gmail.com',
'banhtumy90@gmail.com',
'bichtien201091@gmail.com',
'btpuyen94@gmail.com',
'buitrungnguyen298@gmail.com',
'camnguyen1781990@gmail.com',
'camtu.phanam@gmail.com',
'canh.oseven@gmail.com',
'caothiminhhien@gmail.com',
'chauld81@gmail.com',
'chulong85vt@gmail.com',
'ctphanamkhanhhoa@gmail.com',
'Cuong.naga.vn@gmail.com',
'cuonghv0702@gmail.com',
'cuongpham20031991@gmail.com',
'cuongtnt1987@gmail.com',
'D.HOOFU95@gmail.com',
'dannguyen7892@gmail.com',
'daothimanhhienetc@gmail.com',
'datbmw2798@gmail.com',
'dattienhung@gmail.com',
'diadang1808@gmail.com',
'dieptrinhtran9898@gmail.com',
'dinhcongthang1908@gmail.com',
'dinhhoa.86bb@gmail.com',
'dinhthanhmerap@gmail.com',
'dinhthetruyen282@gmail.com',
'dinhthicuc@gmail.com',
'dluan449@gmail.com',
'dothuquynh612@gmail.com',
'dsminhnhan@gmail.com',
'dsphanthithanhthuy@gmail.com',
'dtnhan194@gmail.com',
'ducda2013@gmail.com',
'dunganh1209@gmail.com',
'duomphanam2022@gmail.com',
'duongbe250493@gmail.com',
'duongxuancong1210@gmail.com',
'duyanh0630@gmail.com',
'duychungle@gmail.com',
'dxdmerap@gmail.com',
'fullhouse.qnvh@gmail.com',
'giangho21@gmail.com',
'giangtc1593@gmail.com',
'giavinh84@gmail.com',
'giavu201188@gmail.com',
'gmlcanhancuatu@gmail.com',
'hahao91.vp@gmail.com',
'hanatran1982@gmail.com',
'hanhtnmt1993@gmail.com',
'happyvu76@gmail.com',
'haquocvinh@gmail.com',
'Hathanh410@gmail.com',
'hathuong44@gmail.com',
'haunguyentan2212@gmail.com',
'hauphung230598@gmail.com',
'hienthao8589@gmail.com',
'hieplucvo@gmail.com',
'hieuphanam2022@gmail.com',
'hoaithumerap2008@gmail.com',
'hoangai43@gmail.com',
'hoangblack18@gmail.com',
'hoangdat240297@gmail.com',
'hoanghanpc4560@gmail.com',
'hoanghiepbinhdinh@gmail.com',
'hoanghuy668@gmail.com',
'hoangphuc541986@gmail.com',
'hoangthesoai@gmail.com',
'hoangvo1513@gmail.com',
'hoangvt1707@gmail.com',
'hogam84@gmail.com',
'holoc1995@gmail.com',
'homanhtuong18111986@gmail.com',
'hongphucle197979@gmail.com',
'hongthuymerap@gmail.com',
'hoxuanthang160688@gmail.com',
'hqhung1844@gmail.com',
'htphuong1208@gmail.com',
'huacongvan@gmail.com',
'hungcv603@gmail.com',
'hungdan1123@gmail.com',
'hungkevin56@gmail.com',
'hungpt3754@gmail.com',
'hungtaytg@gmail.com',
'huonggiam020@gmail.com',
'huyen07k3@gmail.com',
'huyhuynhueh@gmail.com',
'huyluan.nguyen1991@gmail.com',
'huynhphuocthuan1@gmail.com',
'huytuynguyen1995@gmail.com',
'incongthinh66@gmail.com',
'khanghoangtrannb@gmail.com',
'khanhtc101@gmail.com',
'khanhvy12994@gmail.com',
'Kimhangpharma@gmail.com',
'kimyenpharma52@gmail.com',
'laixuannghia84@gmail.com',
'lananhh2095@gmail.com',
'langtoicx@gmail.com',
'lanhcao94@gmail.com',
'lapnguyen.0410@gmail.com',
'lebamanh93dhv@gmail.com',
'lebaohuy@gmail.com',
'lechau13579@gmail.com',
'Lehanhvy2016@gmail.com',
'lehieuttth@gmail.com',
'lehuuhai.tiger@gmail.com',
'lehuybean1997@gmail.com',
'lengocdiem93@gmail.com',
'lengocquykt@gmail.com',
'lequanbaotgdd95@gmail.com',
'lequanghoa.qtkd@gmail.com',
'lequochoa67@gmail.com',
'lequymyhiep@gmail.com',
'lequythimyhoa@gmail.com',
'lesonthach6178@gmail.com',
'lethanhvu2729@gmail.com',
'Lethuong342012@gmail.com',
'letuanhl8388@gmail.com',
'levansam26041987@gmail.com',
'lieulth8889@gmail.com',
'lieumerap@gmail.com',
'linhvtt2007@gmail.com',
'llyhoangll@gmail.com',
'loannguyenthuykim@gmail.com',
'luankttm@gmail.com',
'luatptt2010@gmail.com',
'luongductien@gmail.com',
'luukimhung.thainguyen@gmail.com',
'lynguyenthi08@gmail.com',
'maiphuong.png@gmail.com',
'maitrung335@gmail.com',
'maituyetlinh92@gmail.com',
'mer.baclieu@gmail.com',
'minhphutran@gmail.com',
'minhtrong02752@gmail.com',
'minhtuan1204@gmail.com',
'Mr.donbacninh99@gmail.com',
'mr.levanthai.hk.2709@gmail.com',
'mrquynhnhu@gmail.com',
'myanh0112@gmail.com',
'mylinhng.mr@gmail.com',
'mynga0510@gmail.com',
'namnguyenpr123@gmail.com',
'namnh608@gmail.com',
'NgaLe1201hp@gmail.com',
'nganguyen0685@gmail.com',
'nganpt918@gmail.com',
'nghiaasd1@gmail.com',
'Ngo.Tho.Nguyen91@gmail.com',
'ngockhoa026@gmail.com',
'ngocmankt@gmail.com',
'ngoctruongpham7676@gmail.com',
'ngocuong14sh0101@gmail.com',
'ngovu0310@gmail.com',
'nguoihungsaohoa777@gmail.com',
'nguyen.phong162001@gmail.com',
'nguyen.trang960522@gmail.com',
'NguyenCamThu.tvn0606@gmail.com',
'nguyenchanh.21081994@gmail.com',
'nguyenchiem1990@gmail.com',
'nguyencongvanddt@gmail.com',
'nguyendatienhd1990@gmail.com',
'nguyenduy01052010@gmail.com',
'nguyenhoangvien11@gmail.com',
'nguyenhongha0810628@gmail.com',
'nguyenhuuchi19942606@gmail.com',
'nguyenhuutoan031089@gmail.com',
'nguyenkhang1688@gmail.com',
'nguyenmaikhanh27071988@gmail.com',
'nguyenmaitrang.0210@gmail.com',
'nguyenminh.sontay.hn@gmail.com',
'Nguyenminhhoangoanh96@gmail.com',
'nguyenminhtiep191094@gmail.com',
'nguyenminhtrieu010203@gmail.com',
'nguyenngoctramct1994@gmail.com',
'nguyentantho3110@gmail.com',
'nguyenthevu78@gmail.com',
'nguyenthidungetc@gmail.com',
'nguyenthihongnhung010378@gmail.com',
'nguyenthiloan260893@gmail.com',
'nguyenthingocdiep84@gmail.com',
'nguyenthitrucly9496@gmail.com',
'nguyenthochien2015@gmail.com',
'nguyentientan.161292@gmail.com',
'Nguyentoan4295@gmail.com',
'nguyentrongtay@gmail.com',
'nguyentrungtien201089@gmail.com',
'nguyentuan140593@gmail.com',
'nguyenvancongcp84@gmail.com',
'Nguyenxuan8710@gmail.com',
'nguyenxuankiet090584@gmail.com',
'nguyenxuantu1988@gmail.com',
'NguyenXuanViet1402@gmail.com',
'nhathpv291198@gmail.com',
'niphanam88@gmail.com',
'nnthientrang33@gmail.com',
'oanhthang9896@gmail.com',
'p11nthung@gmail.com',
'phamminhthu294@gmail.com',
'phamngocthongpnt84@gmail.com',
'phamnhatvinh92@gmail.com',
'phamphuonglh@gmail.com',
'phamquynhphanam79@gmail.com',
'phamthanhthuy01071982@gmail.com',
'phamtrangvc0504@gmail.com',
'phamtuandt024@gmail.com',
'phamtuyetmai2710@gmail.com',
'phanbinhmr@gmail.com',
'phanduythong2021@gmail.com',
'phansyloc91@gmail.com',
'phanthibinhkhe@gmail.com',
'phanthiphuong101@gmail.com',
'phucle111095@gmail.com',
'phungxuanle1987@gmail.com',
'phuongloan22021992@gmail.com',
'pt.vinh17@gmail.com',
'pvnlong@gmail.com',
'qdungk13@gmail.com',
'quangthuy113@gmail.com',
'quanminhhau@gmail.com',
'quetran.truong@gmail.com',
'samhoang116@gmail.com',
'seahorse6879@gmail.com',
'sonpharma85@gmail.com',
'tainguyenthanhct118@gmail.com',
'taiphanam@gmail.com',
'tam01237691858@gmail.com',
'tamkt1984@gmail.com',
'Tamphat2603@gmail.com',
'Tanngoctan2010@gmail.com',
'thaiduypc@gmail.com',
'thailong.tanlong@gmail.com',
'thaingoc0210@gmail.com',
'thanhhoang.pharma@gmail.com',
'thanhnguyenfw13@gmail.com',
'thanhnltv92@gmail.com',
'thanhpain@gmail.com',
'thanhphucmai@gmail.com',
'Thanhquang302@gmail.com',
'thanhsonbg.vnn@gmail.com',
'thanhtra270696@gmail.com',
'thanhvyhoavc@gmail.com',
'thiennhan18012016@gmail.com',
'thinh181184@gmail.com',
'thinhduoc@gmail.com',
'thinhle1123@gmail.com',
'thucuc1004@gmail.com',
'thusuong2594@gmail.com',
'ThuygeminiVt3@gmail.com',
'thuyktt1979@gmail.com',
'Thuymerap1985@gmail.com',
'Thuyphamthi994@gmail.com',
'Tientdb@gmail.com',
'tinhnguyen.phar@gmail.com',
'tkhtram95cmu@gmail.com',
'toan.tran00191@gmail.com',
'toanbs1972@gmail.com',
'toanvk501@gmail.com',
'trahuynhy@gmail.com',
'tramtramag1995@gmail.com',
'trancaonam1992@gmail.com',
'trancongphu0703@gmail.com',
'trangnn79@gmail.com',
'tranhien.bh1995@gmail.com',
'tranhoanmy117@gmail.com',
'tranmanhtrung.bg@gmail.com',
'tranngocbang2511@gmail.com',
'tranquang8383@gmail.com',
'Tranquangkha6868@gmail.com',
'tranquyky2016@gmail.com',
'tranquynh08041997@gmail.com',
'tranquynh526@gmail.com',
'trantam0717@gmail.com',
'trantham802@gmail.com',
'Tranthaolevy@gmail.com',
'tranthuthuy0225@gmail.com',
'travanthuc@gmail.com',
'trung96nguyen@gmail.com',
'trungbamepharm@gmail.com',
'Trungbeo8982@gmail.com',
'TrungNA1976@gmail.com',
'truonght38@gmail.com',
'truongnguyenchidung@gmail.com',
'tttai1499@gmail.com',
'tuan94dl@gmail.com',
'tuananh161292@gmail.com',
'tuanlai668359@gmail.com',
'tunglv101@gmail.com',
'tungxenqs@gmail.com',
'tuyen567567@gmail.com',
'tuyettrinh859@gmail.com',
'vancaoarc@gmail.com',
'vanloan25032019@gmail.com',
'Vanthingochuyen711@gmail.com',
'vantiendhho6@gmail.com',
'vantoan.ldtbxhgialai@gmail.com',
'vantuan90pm@gmail.com',
'vanvinh131188@gmail.com',
'vbien.hus@gmail.com',
'vinhpt.phanam@gmail.com',
'vlttrang2308@gmail.com',
'vo90ngoc@gmail.com',
'vothanhquynh1997@gmail.com',
'vothiqui96@gmail.com',
'vuhoi271092@gmail.com',
'vuthanhquy2293@gmail.com',
'vuthevan2021@gmail.com',
'vuthuhai75@gmail.com',
'vvcuong0186@gmail.com',
'xuanmanxd82@gmail.com',
'xuannhulu97@gmail.com',
'xuantrongqn1989@gmail.com',
'xuantupham79@gmail.com'
]
