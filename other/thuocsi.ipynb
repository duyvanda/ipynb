# %%
from selenium import webdriver
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8768/2579501256.py in <module>
# ----> 1 from selenium import webdriver
#
# ModuleNotFoundError: No module named 'selenium'

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url_path = 'https://thuocsi.vn/product/xit-xisat-xanh-nguoi-lon-merap--c-75ml'

# %%
r= requests.get(url_path).text

# %%
with open('file.html', 'w', encoding='utf8') as file:
    file.write(r)

# %%
with open('file.html', 'r', encoding='utf8') as file:
    soup = BeautifulSoup(file)

# %%
soup = BeautifulSoup(r)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="no-cache" http-equiv="Cache-Control"/>
#   <meta content="-1" http-equiv="Expires"/>
#   <meta content="thuốc sỉ" name="keywords"/>
#   <title>
#    Tra cứu và đặt thuốc giá sỉ nhanh tại thuocsi.vn
#   </title>
#   <link href="/images/favicon.ico" rel="shortcut icon"/>
#   <link href="/images/favicon-16x16.png" rel="shortcut icon" type="image/png"/>
#   <link href="/images/favicon-32x32.png" rel="shortcut icon" type="image/png"/>
#   <link href="/images/favicon-96x96.png" rel="shortcut icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <script async="" defer="" src="https://thuocsivn.api.useinsider.com/ins.js?id=10004349">
#   </script>
#   <meta content="12" name="next-head-count"/>
#   <meta charset="utf-8"/>
# ...

# %%
soup = BeautifulSoup(html_text)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="no-cache" http-equiv="Cache-Control"/>
#   <meta content="-1" http-equiv="Expires"/>
#   <meta content="thuốc sỉ" name="keywords"/>
#   <title>
#    Tra cứu và đặt thuốc giá sỉ nhanh tại thuocsi.vn
#   </title>
#   <link href="/images/favicon.ico" rel="shortcut icon"/>
#   <link href="/images/favicon-16x16.png" rel="shortcut icon" type="image/png"/>
#   <link href="/images/favicon-32x32.png" rel="shortcut icon" type="image/png"/>
#   <link href="/images/favicon-96x96.png" rel="shortcut icon" type="image/png"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <script async="" defer="" src="https://thuocsivn.api.useinsider.com/ins.js?id=10004349">
#   </script>
#   <meta content="12" name="next-head-count"/>
#   <meta charset="utf-8"/>
# ...
