# %%
pwd
# Out:
# 'C:\\Users\\DELL'

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('raw_data.csv')
df
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,53,59) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       MaCongTy/CN                                         CongTy/CN  \
# 0          MR0001                      CÔNG TY CỔ PHẦN DƯỢC PHA NAM
# 1          MR0001                      CÔNG TY CỔ PHẦN DƯỢC PHA NAM
# 2          MR0001                      CÔNG TY CỔ PHẦN DƯỢC PHA NAM
# 3          MR0001                      CÔNG TY CỔ PHẦN DƯỢC PHA NAM
# 4          MR0001                      CÔNG TY CỔ PHẦN DƯỢC PHA NAM
# ...           ...                                               ...
# 43714      MR0016  CÔNG TY CỔ PHẦN DƯỢC PHA NAM - CHI NHÁNH CẦN THƠ
# 43715      MR0016  CÔNG TY CỔ PHẦN DƯỢC PHA NAM - CHI NHÁNH CẦN THƠ
# 43716      MR0016  CÔNG TY CỔ PHẦN DƯỢC PHA NAM - CHI NHÁNH CẦN THƠ
# ...

# %%
df['MaKenhKH'].value_counts()
# Out:
# OTC     39698
# CLC      2629
# INS      1171
# DLPP      218
# NB          3
# Name: MaKenhKH, dtype: int64

# %%
df.shape
# Out:
# (43719, 66)

# %%
df = df[df['MaSanPham'].str[:1] != 'V']

# %%
df = df[df['MaKenhKH'] != 'NB']

# %%
df.shape
# Out:
# (42190, 66)
