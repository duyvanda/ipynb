# %%
import httplib2
import os
from google.oauth2 import service_account
from googleapiclient import discovery
import pandas as pd

# %%
url='https://drive.google.com/file/d/1bhb_Rh3Kpm8W0le7VY1TFB2soZvfryPS/view?usp=sharing'
file_id=url.split('/')[-2]
dwn_url='https://drive.google.com/uc?id=' + file_id
df_dan_so = pd.read_csv(dwn_url)
print(df.head())
# Out:
#       TenTinhKH  DoanhSo(CoVAT)
# 11628   Bắc Kạn         1980000
# 12403   Bắc Kạn        21660000
# 12404   Bắc Kạn         8340000
# 18027   Bắc Kạn         1665000
# 18028   Bắc Kạn               0

# %%
https://drive.google.com/file/d/1mwy3WmRATps0t36_kesuEY8Thbi4XgzW/view?usp=sharing

# %%
url='https://drive.google.com/file/d/1mwy3WmRATps0t36_kesuEY8Thbi4XgzW/view?usp=sharing'
file_id=url.split('/')[-2]
dwn_url='https://drive.google.com/uc?id=' + file_id
df_sales = pd.read_csv(dwn_url)
df_sales.columns
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,53,59) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Index(['MaCongTy/CN', 'CongTy/CN', 'NgayChungTu', 'SoDonDatHang',
#        'SoDonTraHang', 'NgayTraHang', 'HoaDon', 'NgayToiHanTT', 'SoHopDong',
#        'TrangThai', 'MaKHThue', 'TenKHThue', 'MaSoThue', 'MaKHDMS', 'MaKHCu',
#        'TenKhachHang', 'DiaChiKH', 'MaVungBH', 'TenVungBH', 'MaKhuVuc',
#        'TenKhuVuc', 'MaTinhKH', 'TenTinhKH', 'MaQuan/HUyen', 'TenQuan/HUyen',
#        'Phuong/Xa', 'MaKenhKH', 'TenKenhKH', 'MaKenhPhu', 'TenKenhPhu',
#        'MaHCO', 'TenHCO', 'MaPhanLoaiHCO', 'TenPhanLoaiHCO', 'MaPhanHangHCO',
#        'TenPhanHangHCO', 'MaSanPham', 'TenSanPhamNB', 'TenSanPhamVietTat',
#        'SoLo', 'SoLuong', 'DonGia(CoVAT)', 'DoanhSo(CoVAT)', 'DonGia(ChuaVAT)',
#        'DoanhSo(ChuaVAT)', 'NgayDatDon', 'NguoiTaoDon', 'NgayGiaoHang', 'MaNV',
#        'TenCVBH', 'MaNVGH', 'NguoiGiaohang', 'TrangThaiGiaoHang', 'SoXuatHang',
#        'DonViGiaoHang', 'TenNhaVanChuyen', 'SoXe', 'NguoiChiuTrachNhiemNo',
#        'KieuDonHang', 'MaLyDo', 'MaCSBH', 'MaCTKM', 'MaCTTL', ' Mã Sản Phẩm',
#        ' Ngành Hàng', 'DanSo'],
#       dtype='object')

# %%
https://drive.google.com/file/d/15ClbdtRJhqF6bIDNgRLqI1wAytIoPWWR/view?usp=sharing
# Out:
#   File "<ipython-input-3-b0f3c28561bf>", line 1
#     https://drive.google.com/file/d/15ClbdtRJhqF6bIDNgRLqI1wAytIoPWWR/view?usp=sharing
#           ^
# SyntaxError: invalid syntax

# %%
url_product='https://drive.google.com/file/d/15ClbdtRJhqF6bIDNgRLqI1wAytIoPWWR/view?usp=sharing'
file_id_product=url_product.split('/')[-2]
dwn_url_product='https://drive.google.com/uc?id=' + file_id
df_product = pd.read_csv(dwn_url)

# %%
df_product.columns
# Out:
# Index([' Mã Sản Phẩm', ' Tên Sản Phẩm', ' Tên Viết Tắt', ' Tên Xuất Hoá Đơn',
#        ' Ngành Hàng', ' Nhãn Hàng', ' Nhóm Sản Phẩm', ' Thuế Suất',
#        ' Danh Mục Sản Phẩm', ' Số Visa', ' Ngày Cấp Visa',
#        ' Ngày Hết Hạn Visa', ' ĐV Lưu Kho', ' ĐV Mua', ' ĐV Bán',
#        ' Giá Bán Gồm VAT', ' Mã NCC', ' Tên NCC', ' Nhà Sản Xuất',
#        ' Nhà Phân Phối', ' Điều Kiện Bảo Quản', ' Nhóm Ưu Tiên', ' Chất Lượng',
#        ' Hình Thức', ' Thành Phần Công Dụng', ' Kích Cỡ', ' Màu', ' Kiểu Dáng',
#        ' Số Hộp/Thùng', ' Quy Cách Đóng Gói', ' Thể Tích ĐV Lưu Kho',
#        ' Trọng Lượng ĐV Lưu Kho', ' Rộng ĐV Lưu Kho', ' Cao ĐV Lưu Kho',
#        ' Dài ĐV Lưu Kho', ' Đơn Vị SP Theo ĐV Khác', ' Thể Tích ĐV Khác',
#        ' Trọng Lượng ĐV Khác', ' Rộng ĐV Khác', ' Cao ĐV Khác', ' Dài ĐV Khác',
#        ' SP Có Lot', ' Thời Gian Bắt Đầu SP', ' Thời Gian Kết Thúc SP',
#        ' Đơn Vị Tính Chẵn', ' Tên Đơn Vị Tính Chẵn', ' Đơn Vị Tính Lẻ',
#        ' Tên Đơn Vị Tính Lẻ', ' Trạng Thái'],
#       dtype='object')

# %%
df_test1 = df_sales[['MaSanPham','DoanhSo(CoVAT)']]
df_test1.merge(df_product[[' Mã Sản Phẩm',' Ngành Hàng']], how = 'left',left_on='MaSanPham', right_on=' Mã Sản Phẩm',suffixes=('_left', '_right'), validate="m:1")
# Out:
#       MaSanPham  DoanhSo(CoVAT)  Mã Sản Phẩm               Ngành Hàng
# 0         EH109        32500000        EH109  Kháng sinh - Kháng viêm
# 1         EH111         7656000        EH111       Tiêu Hoá - Gan Mật
# 2         EH111        25344000        EH111       Tiêu Hoá - Gan Mật
# 3         EH113         5217000        EH113                  Nhỏ Mắt
# 4         EH113        13283000        EH113                  Nhỏ Mắt
# ...         ...             ...          ...                      ...
# 41215     OH075          235000        OH075             Sản Phụ Khoa
# 41216     OH031          684000        OH031                  Nhỏ Mắt
# 41217     OH031               0        OH031                  Nhỏ Mắt
# 41218     OH077          414000        OH077             Sản Phụ Khoa
# 41219     OH078          414000        OH078             Sản Phụ Khoa
#
# [41220 rows x 4 columns]

# %%
df_test1
# Out:
#       MaSanPham  DoanhSo(CoVAT)
# 0         EH109        32500000
# 1         EH111         7656000
# 2         EH111        25344000
# 3         EH113         5217000
# 4         EH113        13283000
# ...         ...             ...
# 41215     OH075          235000
# 41216     OH031          684000
# 41217     OH031               0
# 41218     OH077          414000
# 41219     OH078          414000
#
# [41220 rows x 2 columns]

# %%
df = df_sales[['TenTinhKH','DoanhSo(CoVAT)']]
df = df[df['TenTinhKH'] == 'Bắc Kạn']

# %%
df
# Out:
#       TenTinhKH  DoanhSo(CoVAT)
# 11628   Bắc Kạn         1980000
# 12403   Bắc Kạn        21660000
# 12404   Bắc Kạn         8340000
# 18027   Bắc Kạn         1665000
# 18028   Bắc Kạn               0

# %%
df.merge(df_dan_so, how = 'left',left_on='TenTinhKH', right_on='TenTinhKH',suffixes=('_left', '_right'), validate="m:1")
# Out:
#   TenTinhKH  DoanhSo(CoVAT)  DanSo
# 0   Bắc Kạn         1980000    NaN
# 1   Bắc Kạn        21660000    NaN
# 2   Bắc Kạn         8340000    NaN
# 3   Bắc Kạn         1665000    NaN
# 4   Bắc Kạn               0    NaN

# %%
df_test
# Out:
#       TenTinhKH  DoanhSo(CoVAT)
# 0       Đắk Lắk        32500000
# 1       Đắk Lắk         7656000
# 2       Đắk Lắk        25344000
# 3      Lâm Đồng         5217000
# 4      Lâm Đồng        13283000
# ...         ...             ...
# 41215  Trà Vinh          235000
# 41216  An Giang          684000
# 41217  An Giang               0
# 41218  An Giang          414000
# 41219  An Giang          414000
#
# [41220 rows x 2 columns]

# %%
dwn_url
# Out:
# 'https://drive.google.com/uc?id=1bhb_Rh3Kpm8W0le7VY1TFB2soZvfryPS'

# %%
file_id
# Out:
# '1bhb_Rh3Kpm8W0le7VY1TFB2soZvfryPS'

# %%
url_dan_so= 'https://drive.google.com/file/d/1bhb_Rh3Kpm8W0le7VY1TFB2soZvfryPS/view?usp=sharing'
file_id_dan_so=url_dan_so.split('/')[-2]
dwn_url_dan_so='https://drive.google.com/uc?id=' + file_id_dan_so
df_dan_so = pd.read_csv(dwn_url_dan_so)

# %%
df_dan_so.head()
# Out:
#            TenTinhKH    DanSo
# 0           An Giang  1908352
# 1  Bà Rịa - Vũng Tàu  1148313
# 2          Bắc Giang  1803950
# 3          Bắc Kạn   313905
# 4           Bạc Liêu   907236

# %%
url_dan_so
# Out:
# 'https://drive.google.com/file/d/1bhb_Rh3Kpm8W0le7VY1TFB2soZvfryPS/view?usp=sharing'

# %%
file_id_dan_so
# Out:
# '1bhb_Rh3Kpm8W0le7VY1TFB2soZvfryPS'

# %%
df_dan_so = df_dan_so[df_dan_so['TenTinhKH'] == 'Bắc Kạn']
df_dan_so.head()
# Out:
#    TenTinhKH   DanSo
# 3  Bắc Kạn  313905

# %%
# Out:
# Series([], Name: TenTinhKH, dtype: object)

# %%
url_dan_so='https://drive.google.com/file/d/1bhb_Rh3Kpm8W0le7VY1TFB2soZvfryPS/view?usp=sharing'
file_id_dan_so=url_dan_so.split('/')[-2]
dwn_url_dan_so='https://drive.google.com/uc?id=' + file_id

# %%
dwn_url_dan_so
# Out:
# 'https://drive.google.com/uc?id=15ClbdtRJhqF6bIDNgRLqI1wAytIoPWWR'

# %%
df_dan_so
# Out:
#      Mã Sản Phẩm          Tên Sản Phẩm  Tên Viết Tắt      Tên Xuất Hoá Đơn  \
# 0       CHUACODE             Chưa Code      chuacode           AQUIMA chai
# 1     CK-VOUCHER      Voucher mua hàng           NaN      Voucher mua hàng
# 2           DV01    Tài trợ đơn vị cái           NaN    Tài trợ đơn vị cái
# 3           DV02    Tài trợ đơn vị hộp           NaN    Tài trợ đơn vị hộp
# 4           DV03     Tài trợ đơn vị bộ           NaN     Tài trợ đơn vị bộ
# ..           ...                   ...           ...                   ...
# 710      VT04771      Sticker Ferritox           NaN      Sticker Ferritox
# 711      VT04772   Brochure Shema Topi           NaN   Brochure Shema Topi
# 712      VT04773        Phiếu khảo sát           NaN        Phiếu khảo sát
# 713      VT04774  Tờ hướng dẫn Mepatyl           NaN  Tờ hướng dẫn Mepatyl
# 714       VTTT01      Sản phẩm tài trợ           NaN      Sản phẩm tài trợ
#
#                    Ngành Hàng          Nhãn Hàng      Nhóm Sản Phẩm  \
# 0          Tiêu Hoá - Gan Mật              Thuốc             AQUIMA
# 1    Hàng Khuyến Mãi Tặng Kèm    Hàng Khuyến Mãi    Hàng Khuyến Mãi
# 2            Sản Phẩm Dịch Vụ   Sản Phẩm Dịch Vụ        SP Dịch Vụ
# 3            Sản Phẩm Dịch Vụ   Sản Phẩm Dịch Vụ        SP Dịch Vụ
# 4            Sản Phẩm Dịch Vụ   Sản Phẩm Dịch Vụ        SP Dịch Vụ
# ..                        ...                ...                ...
# 710        Vật Tư Trình Duyệt  Vật Tư Trình Dược  Vật Tư Trình Dược
# 711        Vật Tư Trình Duyệt  Vật Tư Trình Dược  Vật Tư Trình Dược
# 712        Vật Tư Trình Duyệt  Vật Tư Trình Dược  Vật Tư Trình Dược
# 713        Vật Tư Trình Duyệt  Vật Tư Trình Dược  Vật Tư Trình Dược
# 714          Sản Phẩm Dịch Vụ   Sản Phẩm Dịch Vụ        SP Dịch Vụ
#
#       Thuế Suất         Danh Mục Sản Phẩm  Số Visa  ...  Cao ĐV Khác  \
# 0             5              Sản Phẩm Bán      NaN  ...            0
# 1             0  Hàng khuyến mãi tặng kèm      NaN  ...            0
# 2            10          Sản Phẩm Tài Trợ      NaN  ...            0
# 3            10          Sản Phẩm Tài Trợ      NaN  ...            0
# 4            10          Sản Phẩm Tài Trợ      NaN  ...            0
# ..          ...                       ...      ...  ...          ...
# 710          10         Vật Tư Trình Dược      NaN  ...            0
# 711          10         Vật Tư Trình Dược      NaN  ...            0
# 712          10         Vật Tư Trình Dược      NaN  ...            0
# 713          10         Vật Tư Trình Dược      NaN  ...            0
# 714          10          Sản Phẩm Tài Trợ      NaN  ...            0
#
#      Dài ĐV Khác           SP Có Lot  Thời Gian Bắt Đầu SP  \
# 0              0     Sản Phẩm Có Lot            01/01/2020
# 1              0     Sản Phẩm Có Lot            31/12/2020
# 2              0  Sản Phẩm Không Lot            02/05/2021
# 3              0  Sản Phẩm Không Lot            02/05/2021
# 4              0  Sản Phẩm Không Lot            02/05/2021
# ..           ...                 ...                   ...
# 710            0     Sản Phẩm Có Lot            31/12/2020
# 711            0     Sản Phẩm Có Lot            31/12/2020
# 712            0     Sản Phẩm Có Lot            31/12/2020
# 713            0     Sản Phẩm Có Lot            31/12/2020
# 714            0  Sản Phẩm Không Lot            04/05/2021
#
#      Thời Gian Kết Thúc SP   Đơn Vị Tính Chẵn  Tên Đơn Vị Tính Chẵn  \
# 0               31/12/2021                  1                   Hộp
# 1               31/12/2021                  1                   Cái
# 2               02/05/2029                  1                   Cái
# 3               02/05/2029                  1                   Hộp
# 4               02/05/2029                  1                    Bộ
# ..                     ...                ...                   ...
# 710             31/12/2021                  1                   Cái
# 711             31/12/2022                  1                   Cái
# 712             31/12/2021                  1                    Tờ
# 713             31/12/2021                  1                    Tờ
# 714             04/05/2029                  1                   Cái
#
#      Đơn Vị Tính Lẻ  Tên Đơn Vị Tính Lẻ    Trạng Thái
# 0                20                 Gói  Đang Sử Dụng
# 1                 1                 Cái  Đang Sử Dụng
# 2                 1                 Cái  Đang Sử Dụng
# 3                 1                 Hộp  Đang Sử Dụng
# 4                 1                  Bộ  Đang Sử Dụng
# ..              ...                 ...           ...
# 710               1                 Cái  Đang Sử Dụng
# 711               1                 Cái  Đang Sử Dụng
# 712               1                  Tờ  Đang Sử Dụng
# 713               1                  Tờ  Đang Sử Dụng
# 714               1                 Cái  Đang Sử Dụng
#
# [715 rows x 49 columns]

# %%
scopes = ['https://www.googleapis.com/auth/spreadsheets','https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/drive.file']
jsonfile = os.path.join(os.getcwd(),'datateam1599968716114-6f9f144b4262.json')
credentials = service_account.Credentials.from_service_account_file(jsonfile, scopes = scopes)
service = discovery.build('sheets','v4',credentials = credentials)

# %%
spreadsheets_id ='1qEwviiJcAtvWCLvc-5AXOgidaeHMsi2RWWIKiUehabI'
response = service.spreadsheets().values().get(
    spreadsheetId = spreadsheets_id,
    majorDimension = 'ROWS',
    range = 'capture2106'
).execute()

# %%
columns=response['values'][0]
data=[item for item in response['values'][1:]]
df_raw = pd.DataFrame(data,columns=columns)
df_raw
# Out:
#    A     B      C
# 0  1  1000   vinh
# 1  2  5000  khanh
